# %% [markdown]
# # Writing Control
#
# Here we will use a basic version of active learning to write new points to our collection

# %%
from __private import db

import pandas as pd 

import json
import os

# %%
cols = {'_id',
 'created_at',
 'labels',
 'predict',
 'random_number',
 'text',
 'user'}

# %% [markdown]
# Generate Iterables from the files we need

# %%
def clean(obj):
    """
    removes the keys with $ and adds the predict key
    """
    obj["_id"] = obj["_id"]["$oid"]
    del obj["timestamp"]
    
    return { k:v for k,v in obj.items() if k in cols }


def iter_dir_contents(fpath):
    for fn in os.listdir(fpath):
        fn = fpath + fn
        with open(fn, "r") as f:
            for line in f:
                yield clean(json.loads(line))
                
def data_control():
    path = "/Users/JasonLiu/Downloads/research-data/drinking/split/"
    return iter_dir_contents(path)

# %%
from itpy import Itpy

# %% [markdown]
# collect a handful of tweets

# %%
# %%time
x = Itpy(data_control()).filter(lambda _: _["random_number"] < 0.1)._
# Out:
# CPU times: user 1min 5s, sys: 6.5 s, total: 1min 12s
# Wall time: 1min 13s

# %% [markdown]
# convert to dataframe

# %%
df = pd.DataFrame(x)

# %%
from __private import fs
from classification import dao

# %%
fs.list()
# Out:
# ['alcohol|accuracy:0.8010471204188482|f1:0.82389289392379|type:SVC',
#  'alcohol|accuracy:0.8144269924374636|f1:0.8344577062791905|type:SVC',
#  'alcohol|accuracy:0.8237347294938918|f1:0.8478151682571572|type:SVC',
#  'alcohol|accuracy:0.8289703315881326|f1:0.8509127789046653|type:SVC',
#  'alcohol|accuracy:0.8301337987201861|f1:0.8513238289205702|type:RandomForestClassifier',
#  'first_person_label|accuracy:0.52046783625731|f1:0.5009187878453114|type:SVC',
#  'first_person_label|accuracy:0.5243664717348928|f1:0.508797109912656|type:RandomForestClassifier',
#  'first_person_label|accuracy:0.530214424951267|f1:0.5136580488488517|type:SVC',
#  'first_person_label|accuracy:0.5321637426900585|f1:0.5265047952844989|type:LogisticRegression',
#  'first_person_label|accuracy:0.543859649122807|f1:0.5166687798266746|type:SVC',
#  'first_person_label|accuracy:0.5536062378167641|f1:0.5349297830780407|type:SVC',
#  'first_person_label|accuracy:0.5555555555555556|f1:0.53459052797563|type:RandomForestClassifier',
#  'first_person_label|accuracy:0.5633528265107213|f1:0.5525041327947611|type:LogisticRegression',
#  'first_person|accuracy:0.665389527458493|f1:0.7816666666666666|type:RandomForestClassifier',
#  'first_person|accuracy:0.6743295019157088|f1:0.7822374039282664|type:SVC',
#  'first_person|accuracy:0.6781609195402298|f1:0.7662337662337662|type:LogisticRegression',
#  'first_person|accuracy:0.6807151979565773|f1:0.7743682310469315|type:RandomForestClassifier',
#  'first_person|accuracy:0.6909323116219668|f1:0.7917383820998279|type:SVC',
#  'first_person|accuracy:0.6934865900383141|f1:0.7637795275590552|type:LogisticRegression',
#  'first_person|accuracy:0.6934865900383141|f1:0.7938144329896907|type:SVC',
#  'first_person|accuracy:0.6947637292464879|f1:0.7941429801894918|type:SVC']

# %%
# %%time
clf = dao.ClassifierAccess.get_byfile('first_person|accuracy:0.6947637292464879|f1:0.7941429801894918|type:SVC')
# Out:
# CPU times: user 360 ms, sys: 191 ms, total: 551 ms
# Wall time: 3.76 s

# %%
# %%time
y = clf.predict_proba(df)
# Out:
# CPU times: user 2min 15s, sys: 1.18 s, total: 2min 17s
# Wall time: 2min 16s

# %%
# %%time
clf2 = dao.ClassifierAccess.get_byfile('alcohol|accuracy:0.8289703315881326|f1:0.8509127789046653|type:SVC')
# Out:
# CPU times: user 39.3 ms, sys: 26.7 ms, total: 66 ms
# Wall time: 1.06 s

# %%
# %%time
y2 = clf2.predict_proba(df)
# Out:
# CPU times: user 15.7 s, sys: 93.9 ms, total: 15.8 s
# Wall time: 15.7 s

# %%
df["i_first_person"] = y[:,1]

# %%
df["i_alcohol"] = y2[:,1]

# %%
df["control"] = 1

# %%
df_temp = df[
    (df.i_alcohol > .5) &
    (df.i_first_person > .5) &
    (df.text.str.len() > 40)][["_id", "created_at", "text", "user", "control", "i_alcohol", "i_first_person"]]

# %%
df_temp
# Out:
#                             _id                      created_at  \
# 6      556ba147d6dfbb336fb8b5e3  Mon Jun 01 00:03:56 +0000 2015
# 7      556ba15ed6dfbb336fb8b6a8  Mon Jun 01 00:04:18 +0000 2015
# 9      556ba1afd6dfbb336fb8b9ff  Mon Jun 01 00:05:40 +0000 2015
# 12     556ba1ced6dfbb336fb8bb17  Mon Jun 01 00:06:10 +0000 2015
# 19     556ba263d6dfbb336fb8c141  Mon Jun 01 00:08:40 +0000 2015
# 23     556ba2c8d6dfbb336fb8c582  Mon Jun 01 00:10:21 +0000 2015
# 28     556ba2f8d6dfbb336fb8c77e  Mon Jun 01 00:11:08 +0000 2015
# 32     556ba35fd6dfbb336fb8cb9e  Mon Jun 01 00:12:51 +0000 2015
# 39     556ba403d6dfbb336fb8d238  Mon Jun 01 00:15:37 +0000 2015
# 41     556ba434d6dfbb336fb8d42c  Mon Jun 01 00:16:24 +0000 2015
# 42     556ba44cd6dfbb336fb8d501  Mon Jun 01 00:16:48 +0000 2015
# 50     556ba4ecd6dfbb336fb8db75  Mon Jun 01 00:19:24 +0000 2015
# 62     556ba589d6dfbb336fb8e25a  Mon Jun 01 00:22:06 +0000 2015
# 65     556ba64dd6dfbb336fb8ead4  Mon Jun 01 00:25:22 +0000 2015
# 72     556ba6bbd6dfbb336fb8ef74  Mon Jun 01 00:27:11 +0000 2015
# 78     556ba73ad6dfbb336fb8f519  Mon Jun 01 00:29:19 +0000 2015
# 85     556ba7e1d6dfbb336fb8fc56  Mon Jun 01 00:32:06 +0000 2015
# 89     556ba815d6dfbb336fb8fea0  Mon Jun 01 00:32:58 +0000 2015
# 103    556ba94bd6dfbb336fb90c5a  Mon Jun 01 00:38:08 +0000 2015
# 111    556ba9f6d6dfbb336fb91402  Mon Jun 01 00:40:59 +0000 2015
# 120    556bab0ad6dfbb336fb920bf  Mon Jun 01 00:45:36 +0000 2015
# 122    556bab47d6dfbb336fb92390  Mon Jun 01 00:46:36 +0000 2015
# 127    556bab84d6dfbb336fb92649  Mon Jun 01 00:47:37 +0000 2015
# 137    556babe9d6dfbb336fb92afb  Mon Jun 01 00:49:18 +0000 2015
# 141    556bac3cd6dfbb336fb92ee4  Mon Jun 01 00:50:41 +0000 2015
# 142    556bac43d6dfbb336fb92f3b  Mon Jun 01 00:50:48 +0000 2015
# 80408  AT FUCKING WHOLE FOODS PEOPLE!! - Drinking an ...
#
#                                                     user  control  i_alcohol  \
# 6      {'lang': 'en', 'contributors_enabled': False, ...        1   0.558735
# 7      {'lang': 'en', 'contributors_enabled': False, ...        1   0.647953
# 9      {'lang': 'en', 'contributors_enabled': False, ...        1   0.512692
# 12     {'lang': 'en', 'contributors_enabled': False, ...        1   0.989330
# 19     {'lang': 'en', 'contributors_enabled': False, ...        1   0.959078
# 23     {'lang': 'en', 'contributors_enabled': False, ...        1   0.996679
# 28     {'lang': 'en', 'contributors_enabled': False, ...        1   0.679625
# 32     {'lang': 'en', 'contributors_enabled': False, ...        1   0.955309
# 39     {'lang': 'en', 'contributors_enabled': False, ...        1   0.973367
# 41     {'lang': 'en', 'contributors_enabled': False, ...        1   0.770647
# 42     {'lang': 'en', 'contributors_enabled': False, ...        1   0.865547
# 50     {'lang': 'en', 'contributors_enabled': False, ...        1   0.563064
# 62     {'lang': 'en', 'contributors_enabled': False, ...        1   0.624392
# 65     {'lang': 'en', 'contributors_enabled': False, ...        1   0.899931
# 72     {'lang': 'en', 'contributors_enabled': False, ...        1   0.941172
# 78     {'lang': 'en', 'contributors_enabled': False, ...        1   0.973534
# 85     {'lang': 'en', 'contributors_enabled': False, ...        1   0.807247
# 89     {'lang': 'en', 'contributors_enabled': False, ...        1   0.982617
# 103    {'lang': 'en', 'contributors_enabled': False, ...        1   0.843656
# 111    {'lang': 'en', 'contributors_enabled': False, ...        1   0.946018
# 120    {'lang': 'en', 'contributors_enabled': False, ...        1   0.921386
# 122    {'lang': 'en', 'contributors_enabled': False, ...        1   0.863981
# 127    {'lang': 'en', 'contributors_enabled': False, ...        1   0.878741
# 137    {'lang': 'en', 'contributors_enabled': False, ...        1   0.594666
# 141    {'lang': 'en', 'contributors_enabled': False, ...        1   0.808465
# 142    {'lang': 'en', 'contributors_enabled': False, ...        1   0.799427
# 153    {'lang': 'en', 'contributors_enabled': False, ...        1   0.931417
# 171    {'lang': 'en', 'contributors_enabled': False, ...        1   0.878396
# 174    {'lang': 'en', 'contributors_enabled': False, ...        1   0.999999
# 188    {'lang': 'en', 'contributors_enabled': False, ...        1   0.920351
# ...                                                  ...      ...        ...
# 80236  {'lang': 'en', 'contributors_enabled': False, ...        1   0.603083
# 80245  {'lang': 'en', 'contributors_enabled': False, ...        1   0.704833
# 80248  {'lang': 'en', 'contributors_enabled': False, ...        1   0.868993
# 80249  {'lang': 'en', 'contributors_enabled': False, ...        1   0.955308
# 80261  {'lang': 'en', 'contributors_enabled': False, ...        1   0.678283
# 80270  {'lang': 'en', 'contributors_enabled': False, ...        1   0.895089
# 80273  {'lang': 'en', 'contributors_enabled': False, ...        1   0.908334
# 80278  {'lang': 'en', 'contributors_enabled': False, ...        1   0.690881
# 80283  {'lang': 'en', 'contributors_enabled': False, ...        1   0.875906
# 80284  {'lang': 'en', 'contributors_enabled': False, ...        1   0.941526
# 80288  {'lang': 'en', 'contributors_enabled': False, ...        1   0.869969
# 80290  {'lang': 'en', 'contributors_enabled': False, ...        1   0.908372
# 80302  {'lang': 'en', 'contributors_enabled': False, ...        1   0.662148
# 80312  {'lang': 'en', 'contributors_enabled': False, ...        1   0.928244
# 80317  {'lang': 'en', 'contributors_enabled': False, ...        1   0.960807
# 80318  {'lang': 'en', 'contributors_enabled': False, ...        1   0.770363
# 80320  {'lang': 'en', 'contributors_enabled': False, ...        1   0.730011
# 80327  {'lang': 'en', 'contributors_enabled': False, ...        1   0.982471
# 80343  {'lang': 'en', 'contributors_enabled': False, ...        1   0.715927
# 80345  {'lang': 'en', 'contributors_enabled': False, ...        1   0.917116
# 80351  {'lang': 'en', 'contributors_enabled': False, ...        1   0.777246
# 80352  {'lang': 'en', 'contributors_enabled': False, ...        1   0.940701
# 80359  {'lang': 'en', 'contributors_enabled': False, ...        1   0.890706
# 80360  {'lang': 'en', 'contributors_enabled': False, ...        1   0.971125
# 80362  {'lang': 'en', 'contributors_enabled': False, ...        1   0.531091
# 80366  {'lang': 'en', 'contributors_enabled': False, ...        1   0.997034
# 80376  {'lang': 'en', 'contributors_enabled': False, ...        1   0.999998
# 80379  {'lang': 'en', 'contributors_enabled': False, ...        1   0.941823
# 80404  {'lang': 'en', 'contributors_enabled': False, ...        1   0.826740
# 80408  {'lang': 'en', 'contributors_enabled': False, ...        1   0.777798
#
#        i_first_person
# 6            0.568471
# 7            0.630342
# 9            0.841444
# 12           0.582232
# 19           0.800684
# 23           0.622957
# 28           0.527819
# 32           0.640730
# 39           0.754687
# 41           0.754765
# 42           0.715421
# 50           0.728552
# 62           0.515552
# 65           0.691802
# 72           0.861866
# 78           0.816292
# 85           0.639853
# 89           0.908647
# 103          0.594545
# 111          0.832403
# 120          0.692316
# 122          0.841663
# 127          0.753270
# 137          0.534482
# 141          0.546747
# 142          0.737447
# 153          0.720394
# 171          0.772670
# 174          0.708059
# 188          0.513959
# ...               ...
# 80236        0.671120
# 80245        0.659063
# 80248        0.648145
# 80249        0.724806
# 80261        0.630161
# 80270        0.511547
# 80273        0.704550
# 80278        0.589645
# 80283        0.781862
# 80284        0.767897
# 80288        0.589334
# 80290        0.818058
# 80302        0.687530
# 80312        0.685559
# 80317        0.803151
# 80318        0.789073
# 80320        0.598740
# 80327        0.700612
# 80343        0.821308
# 80345        0.724693
# 80351        0.514097
# 80352        0.662654
# 80359        0.869683
# 80360        0.858185
# 80362        0.604283
# 80366        0.633718
# 80376        0.786746
# 80379        0.655115
# 80404        0.729682
# 80408        0.672027
#
# [11361 rows x 7 columns]

# %%
batch = (v for k,v in df_temp.T.to_dict().items())

# %%
for i in batch:
    try:
        db.insert_one(i)
    except:
        pass

# %%
X = df[
    (df.c1 > .5) &
    (df.c1 < 0.7) & 
    (df.c2 < .6)  & 
    (df.c2 > .5) & 
    (df.text.str.len() > 40)]\
.set_index("_id").sort("random_number")[["text", "random_number"]]

# %%
import datetime

date = str(datetime.date.today())
candidate = X.sort("random_number").head(500)
key = candidate.random_number.apply(hash).sum()

# %%
candidate["text"] = candidate["text"].apply(lambda _: _.encode(encoding='UTF-8'))

# %%
candidate[["text", "random_number"]].to_csv(
    "../amt/c_amt|{}|{}.csv".format(date, key),
)

# %%
c = 0
for i in candidate.index:
    if db.find_one({"_id":i}):
        c += 1

# %%
# %%bash
#
# open .
