# %% [markdown]
# # Developing Iterators for Large Data

# %%
import os
import json

from itpy import Itpy
from itpy.helpers import getitem

from twokenize import twokenize

# %%
def iter_dir_contents(fpath):
    for fn in os.listdir(fpath):
        fn = fpath + fn
        with open(fn, "r") as f:
            for line in f:
                yield json.loads(line)
                
def data_control():
    path = "/Users/JasonLiu/Downloads/research-data/drinking/split/"
    return iter_dir_contents(path)

                
def data_sampled():
    path = "/Users/JasonLiu/Downloads/research-data/nondrinking/split/"
    return iter_dir_contents(path)

# %%
Itpy(data_sampled()).map(getitem("text")).filter(lambda _: "@" in _).slice(5, 10)._
# Out:
# ['@lewischube no never',
#  'I just wanna see @FightOwensFight power bomb Cena on the grates. #WWEChamber',
#  "look @ my man's collar bones and neck in my header hes so gorgeous",
#  "@zackmayes1 @DJohnsonPGA I'll go to the range with you now that I got nice clubs whenever you want man",
#  '@_jennagraziano_ thanks for catching this! this ones original']

# %% [markdown]
# # Training Phrases
#
# ```
# Itpy(data_sampled()).union(data_control())\
#     .map(getitem("text")) \
#     .map(tokenizer.tokenize)
# ```

# %%
from gensim import models, corpora
from twokenize import twokenize as tokenizer

# %%
p2 = models.Phrases.load("./twitter_p2.Phrase")
p3 = models.Phrases.load("./twitter_p3.Phrase")
d1 = corpora.Dictionary.load("./twitter_d1.Dict")
lda100 = models.LdaModel.load("./twitter_topics100.Lda")

# %% [markdown]
# %%time
#
# p2 = models.Phrases(
#     Itpy(data_sampled()).union(data_control())\
#     .map(getitem("text")) \
#     .map(str.lower)
#     .map(tokenizer.tokenize)
# )

# %% [markdown]
# p2.save("./twitter_p2.Phrase")

# %% [markdown]
# %%time
#
# p3 = models.Phrases(p2[
#     Itpy(data_sampled()).union(data_control())\
#     .map(getitem("text")) \
#     .map(str.lower)
#     .map(tokenizer.tokenize)]
# )

# %% [markdown]
# p3.save("./twitter_p3.Phrase")

# %% [markdown]
# %%time
#
# d1 = corpora.Dictionary(p3[p2[
#     Itpy(data_sampled()).union(data_control())\
#     .map(getitem("text")) \
#     .map(str.lower)
#     .map(tokenizer.tokenize)
# ]])

# %% [markdown]
# d1.save("./twitter_d1.Dict")

# %% [markdown]
# # Training LDA

# %% [markdown]
# ```
# c = Itpy(data_sampled()).union(data_control())\
#     .map(getitem("text")) \
#     .map(str.lower) \
#     .map(tokenizer.tokenize) \
#     .map(p2.__getitem__) \
#     .map(p3.__getitem__) \
#     .map(d1.doc2bow)._
# ```

# %%
lda100 = models.LdaModel.load("./twitter_topics100.Lda")

# %%
Itpy(data_sampled()).union(data_control())\
    .map(getitem("text")) \
    .map(str.lower) \
    .map(tokenizer.tokenize) \
    .map(p2.__getitem__) \
    .map(p3.__getitem__) \
    .map(d1.doc2bow) \
    .map(lda100.__getitem__).slice(100)._

# %% [markdown]
# # Exploring Models

# %%
from data.dao import DataAccess

# %%
X = DataAccess.get_as_dataframe()

# %%
X_alch = X[X["labels"].apply(lambda _: _["alcohol"]) == 1]

# %%
topics = X_alch.text.str.lower()\
    .apply(twokenize.tokenize)\
    .map(p2.__getitem__) \
    .map(p3.__getitem__) \
    .map(d1.doc2bow) \
    .map(lda100.__getitem__)

# %%
topics = list(topics)

# %%
from itpy.helpers import try_or

# %%
best_topic = Itpy(topics).map(
    try_or(lambda n: max(n, key=lambda _: _[1])[0],
          lambda n: -1),
                )._

# %%
top_best_topic = Itpy(best_topic).frequency().most_common()

# %% [markdown]
# ## Finding top topics

# %%
import numpy
import scipy.sparse as sparse

def convert2sparse(tokens):
        row, col, data = [], [], []
        for doc_id, document in enumerate(lda100[tokens]):
            for topic_id, weight in document:
                row.append(doc_id)
                col.append(topic_id)
                data.append(weight)
        return sparse.csr_matrix((data, (row, col)))

# %%
topic_values = convert2sparse(topics).sum(0)
document_topic = convert2sparse(topics)
document_topic = numpy.array(document_topic.todense())

# %%
topic2value = list(enumerate((document_topic).mean(0).tolist()))

# %%
topic2value.sort(key=lambda _: -_[1])

# %%
top_topics = [x for x,_ in topic2value[:30]]

# %% [markdown]
# ### Print Top Topics for Alcohol Related

# %%
for _id, c in top_best_topic[:10]:
    print("topic:",_id,"\t" "count:", c, "\n", get_topic_words(lda100.show_topic(_id, 30)))
    print()
# Out:
# topic: 81 	count: 177
#  ['beer', '.', 'he', 'a', 'think', 'i', 'and', ',_az', 'is', 'the', 'with', 'in', 'talented', "didn't", 'for', 'on', 'my', 'book', 'mind', 'to', 'but', 'cocktails', 'at', 'between', 'lunch', 'later', ',', 'delicious', 'lets', 'fly']
#
# topic: 31 	count: 165
#  ['it', 'was', 'i', '.', 'they', 'and', 'the', 'a', 'to', 'but', 'after', 'nigga', 'omg', ',', 'menu_:', 'you_guys', 'dragging', 'no_more', 'talking', "don't_think", 'pour', 'games', 'told_me', 'yep', 'clean', 'led', 'breakfast', "don't_want", 'happened', 'sounds_like']
#
# topic: 76 	count: 143
#  ['have', 'a', 'i', '.', 'her', 'to', 'one', 'and', 'female', 'the', 'home', 'in', 'with', 'for', ';', 'arizona', 'hate', 'but', 'my', 'drive', 'morning', ',', 'at', 'tf', 'bus', 'burger', 'cherry', 'sharing', 'been_drinking', 'yall_females']
#
# topic: 74 	count: 92
#  ['not', '.', "it_'s", 'a', ',', 'but', 'the', 'its', 'and', 'to', 'for', 'in', 'on', 'high', 'would_be', 'beach', 'bring', 'i', 'days', 'with', 'going_to_be', 'works', 'nobody', 'others', 'at', 'closed', 'states', 'boat', 'barely', 'expected']
#
# topic: 14 	count: 91
#  ['drinking', 'only', 'and', 'the', '.', 'said', 'everyone', 'one_of', 'is', 'my', 'i', 'last', 'try', 'in', 'during', 'went', 'at', 'margarita', '@sorryimalex', 'weather', 'it_begins', '😉', 'from_the_beginning', 'session', 'a', "it_'s_been", 'spend', 'homie', 'to_celebrate', 'hour']
#
# topic: 60 	count: 90
#  ['like', 'i', 'or', 'a', '.', 'to', 'never', 'say', 'want', 'best', 'my', 'and', 'but', 'sleep', 'is', 'on', 'bet', 'with', ',', 'customer_service', 'pics', 'whether', 'weeks', 'correct', 'workout', '@flippinginja', 'spin', 'fact', 'matt', 'duck']
#
# topic: 79 	count: 88
#  ['drink', 'a', 'new', 'i', 'and', 'last_night', 'ur', 'dude', 'for', 'week', 'vodka', '❤️', '.', 'dinner', 'movie', 'via', 'room', 'co', 'charging', 'the', 'kale', 'trip', 'begin_with', '👀', 'de_la', 'too_drunk', 'train', 'players', 's/o_to', 'join_us']
#
# topic: 77 	count: 86
#  ['you', 'when', 'i', 'know', 'for', 'to', 'thank_you', '.', 'but', 'water', 'ass', 'on', '😏', 'south', 'my', ',', '8', 'the', 'a', 'wearing', 'my_house', 'yay', 'will_always_support', 'rip', 'thank', 'ways', 'begging_for', 'four', 'wrote', 'publix']
#
# topic: 47 	count: 77
#  ['drunk', 'up', 'drinks', ',_nc', 'and', '#healthcare_#job', 'il', 'winery', 'weather_alert', 'with', 'in', 'gone', 'is', '@iggyazalea', 'area', 'definitely', '.', 'country', 'vote', 'i', 'understand', 'the', 'leggings', 'king', 'shoot', 'videos', 'my', 'court', 'felt', 'energy']
#
# topic: 63 	count: 71
#  ['are', '.', 'the', 'and', 'who', 'a', 'is', 'to', 'life', 'in', ',', 'having', 'for', 'begins', 'with', 'other', 'r', 'coming', "i've", 'woman', 'but', 'close', 'at', 'child', 'lovely', 'each', 'classic', 'age', 'killing', 'hugging']

# %%
X_alch["topics"] = best_topic

# %%
for idx, _ in top_best_topic:
    print(idx)
    print(get_topic_words(lda100.show_topic(idx, 30)))
    print(*list(X_alch[X_alch.topics == idx].text)[:30], sep="\n\n")
    print()
    print()
# Out:
# 81
# ['beer', '.', 'he', 'a', 'think', 'i', 'and', ',_az', 'is', 'the', 'with', 'in', 'talented', "didn't", 'for', 'on', 'my', 'book', 'mind', 'to', 'but', 'cocktails', 'at', 'between', 'lunch', 'later', ',', 'delicious', 'lets', 'fly']
# Stone Cold use to be the baddest MF in my book lol dude use to get hype; whip your ass and waste a case of beer in the ring 😂
#
# Light, but doesn't lack flavor. A good summer beer to drink.... (Bitter Brewer) http://t.co/snpHeJLIM2 #photo
#
# I need a night this summer to sit by a fire and make s'mores and smoke weed and drink beer ok
#
# Had a beer with an ex I havent seen in 2 years so yeah, I am going eat this leftover pizza &amp; fall asleep in my clothes. I earned it.
#
# he straight up drank from my bottle oh my god
#
# We he a little horsey named Paul Revere just me and my homies and a quart of beer.
#
# I just want to drink some beer on a fuggin boat
#
# When you're drunk you're either annoying or funny there is no in between
#
# mike just asked if he should drink a beer before the gym...... what do you think my response was
#
# Why does weird shit only ever seem to happen when your drunk.
#
# Bud light is just a scheme to get you to buy more beer
#
# Burger and beer #1 of the day. @ Goose Island Clybourn https://t.co/hPPTNBrPxu
#
# 9 days straight of work calls for a beer on the beach. @ Zoombezi Bay https://t.co/AVbkpDHKPA
#
# When your mate's beer is on tap AND is the happy hour beer, you drink it.... (Honey Blonde) http://t.co/2Nm0lzX61F #photo
#
# He just drunk a 6oz 🍼 now he sleep!! 👶😴😴
#
# I think @ahleyafuller should bring me 2 beef patties and a kola champagne
#
# I completely underestimated gin. I woke up this morning completely alert with ridiculously clear skin and I didn't drunk dial anyone.
#
# Tried to crush a can at a concert and got beer on a strangers foot #mybizzle
#
# The people who listen to Blink-182 and drink beer at home on a Friday night are my kind of people.
#
# I've been napping (and continuing) since 4.30 feeling drunk every time I try to get up.
#
# Beer, alcohol, and junk food is starting to catch up with me. 🙅🏻🙅🏻
#
# Our friend drank tequila, vodka, whiskey, and beer last night. We know he is dying right now. 😂💀
#
# I mean at 14 dollars a beer guess it adds up quick
#
# There was a keg at his graduation party and I didn't get a beer because I was too busy working cattle and flirting 😓😭😭
#
# A little beer and pizza before @Metallica #xgames @XGames http://t.co/MHn5jXooWD
#
# I think Brian is my man crush. Dude knows everything about beer and has never steered us wrong
#
# I'm a supervisor so let's celebrate but drink half a beer and 3 red bulls face ass.
#
# Nah, just playing. I think I might just go grab a beer and drink with the chase park mafia.
#
# Was able to try out this pretty tasty beer from @dragoonbrewing last night. http://t.co/dDqiTOhWKu
#
# Shopping and beer. Doesn't get better.
#
#
# 31
# ['it', 'was', 'i', '.', 'they', 'and', 'the', 'a', 'to', 'but', 'after', 'nigga', 'omg', ',', 'menu_:', 'you_guys', 'dragging', 'no_more', 'talking', "don't_think", 'pour', 'games', 'told_me', 'yep', 'clean', 'led', 'breakfast', "don't_want", 'happened', 'sounds_like']
# Wtf was I drinking Sunday?😂🔫🙊 http://t.co/3c2mz1Uz8L
#
# I can go through the week without drinking but soon as the weekend hit mannnnn I feel that shit is owed to me
#
# my sister did a nice gesture and put me into bed last night cause I couldn't, I was too drunk
#
# If it ain't ace pour out the whole case we don't drink that‼️
#
# i don't think I'm that southern but tonight i brought up drinking moonshine in high school at work and apparently that's not a normal thing
#
# Such a long day , I need a few drinks after that 🍹🍺🍸🍷🍻
#
# I need two drinks from wet willies soon as I touch down
#
# After tonight. I need a drink. 🍷 http://t.co/kt37NxxFDv
#
# Never heard of fruitvale station before tonight but that movie was good and the ending got to me 😢
#
# @ASUSkip @MeLlamoTrevor Used to go to PHX Muni in 70's and they had 5 cent beer night. Had 2 many problems so raised it to 10 cents.
#
# I had a dream that it was my 21st birthday and I bought so many drinks. Then I woke up and remembered I'm only turning 19. 😭😭😭😔
#
# WOW can we talk about Cirque???? I was so moved and it smelled like red wine and bread
#
# Yeah I got drunk the other night and said some shit to somebody that I never THOUGHT I would say. But I owned up to it. 💯✌ real shit.
#
# They need to make baja blast flavored alcohol. I'd get drunk too fast 😅
#
# #beer #blunts and #Supernatural marathon.
#
# I still have that #cherry beer by @SeagramsEscapes I wonder if I should drink it.  I'd be out the rest of the night. #decisionsdecisions 🍒🍺
#
# @deeemmiii1 chasen and I are getting drunk together soon and your DDing us to a strip club after
#
# Yo I'm drunk AF so if I said anything to you tonight I ment it lmao
#
# Things to do this weekend: cut lawn, pack, bottle beer, and take the kids to their games.
#
# nigga i just drunk that whole bottle
#
# And continuing to be till Edc but after I'm not going to drink as much new change 😊
#
# alot of people forget that Shaq was actually a decent rapper. i've been drinking
#
# I was drunk af otp talkin to Dink Tha Don 😏 abt rekele , bby daddy &amp; dem hoes &amp; she hung up on me 😭 i was mad lol going off
#
# Almost every girl I know hates beer but I actually like it, I used to hate but beer bong changed that for me real quick 😂
#
# I don't think I've ever felt UGLY until right now im@drunk as fuck
#
# We made it! #NewJersey and got a 60 of #vodka for $19 😍😍 gonna explore tonight and cannnnnnot wait… https://t.co/LsFk9nvfRC
#
# Omg I think I'm drunk just that quick!
#
# Trying a new spot. They have ginger beer so I'm good with it. (at @JJBootleggers in Philadelphia, PA) https://t.co/qV6X05Cl4v
#
# Omg @AmoHeals just yelled at me "OMG I want a sloppy bottom!"
# Laughed so hard I had to go to the floor.
#
# (It's a drink name FYI)
#
# "Just did the river float. It was pretty sick, got pretty drunk" 😂😂🍞
#
#
# 76
# ['have', 'a', 'i', '.', 'her', 'to', 'one', 'and', 'female', 'the', 'home', 'in', 'with', 'for', ';', 'arizona', 'hate', 'but', 'my', 'drive', 'morning', ',', 'at', 'tf', 'bus', 'burger', 'cherry', 'sharing', 'been_drinking', 'yall_females']
# I know I'm broke when I have to drink pinacle.
#
# I'm drunk, and i work in the morning
#
# Dj'ed a Casino Royale / Mad Men party last weekend. Still listenin to the crate I made for the gig… https://t.co/sUN0E4R5Ja
#
# Oh man, my head hurts so bad, I should have saved one beer for the hangover...🍺🔇
#
# Pizza for one and wine for seven plz.
#
# Some girl in my English class tried to tell me ButterBeer is only cold. I was getting ready to fight her.
#
# Just one beer. I mean it's 22 ounces and 9.3% alcohol but still one b... (Brainless® Raspberries) http://t.co/VVtygmafzn
#
# Bored and awake so I might as well drive drunk people home if anyone needs a ride.
#
# I'm trying to have a really good Friday night. I want to get drunk and have a crazy time. If i have to work Saturday ima be so crushed
#
# Gonna have a glass of wine
#  Got a book to get lost in
#  Just me, myself,
#  And Miss Jane Austen
#
# "Why do you rely on drinkin/smokin to have a good time?"
#
# Holy shit. I have not been that drunk in so long. And then i remembered I had two shots on top of my two regular drinks. Christ.
#
# I have started drinking in anticipation of the #ChampionsLeagueFinal #fcbarcelona 🍷
#
# Drinking sangria out of a birthday cup at a 10 year olds birthday party #gradlife
#
# i dont like drinking i have to take my clothes off if i get mad a weekend is just a weekend to me i just want a doctor
#
# My mom better have my drinks when I get home. In need of them rn
#
# I picked up my moms drunk ass from blue 32 and took her to the gas station to get me drinks and she stopped to talk to lil kids outside
#
# When your drunk as fuck but got to take the SAT in the morning
#
# I've been up for 2 hours, it's Saturday, and my day off, and I have to be drunk for 7+ hours this makes zero sense tbh
#
# Had a chat with a drunk @Flobfromthepack at 4 in the morning last night lmao
#
# I don't smoke and I'm a bad drunk so idk what to do 😩😂
#
# Wish I had a girl to stay in with that's down to drink some beer and not have to worry about finding something to do every night.
#
# My sister is drunk and deadass is being crazy 😂👀 I wish my mom would just call my grandpa to set her straight rn 👀
#
# Drank stupidly n still managed to drive fucked upp .... fucks with me
#
# I have a headache and I didn't even drink
#
# my mom wants me to get my license so I can drive her home when she gets drunk lmao
#
# Sometimes you just have to text your mom at 10 pm on a Sunday when you're  drunk.
#
# I #amwriting and drinking cake flavored vodka, because why not. Will have lots of editing to do in the morning but at least I am writing.
#
# I currently have 3 beers and a power aid in my fridge. Hopefully we will get some groceries tonight 🍺🍤🍌
#
# Sitting around getting drunk all summer would be the move but i have to go to work and pay Bills
#
#
# 74
# ['not', '.', "it_'s", 'a', ',', 'but', 'the', 'its', 'and', 'to', 'for', 'in', 'on', 'high', 'would_be', 'beach', 'bring', 'i', 'days', 'with', 'going_to_be', 'works', 'nobody', 'others', 'at', 'closed', 'states', 'boat', 'barely', 'expected']
# Haven't been drunk or high in a while.
#
# "I get drunk as fuck and headbutt counters.. it's not a game for me..." - Zach harmon on people thinking they can drink
#
# If we could all just treat each other like drunk girls treat each other in the bathroom at a party. The world would be a great place
#
# Playing house wife for the next two days. Cooking, cleaning and drinking beer. 😎
#
# I'm a little drunk on you &amp; high on summertime🎶
#
# But anyways it's Latin night at pub tonight
#
# You would be surprised how many people ask me to stay for a beer while delivering
#
# so last night, drunk darian needed a mirror and so I took this to see myself. I kinda dig it.
#
# (ft. misty) 😂 http://t.co/g7RgA7c81q
#
# yes. I dabble in the booze.  SO WHAT ASSHOLE.  I CAN HAVE A BEER.  I DONT LIKE DRINKING THAT MUCH. ITS NOT A PLEASENT morning the next day.
#
# I just wanna chill, and drink some brew today.
# Its kinda fucked up how I have Mon &amp; Tue off.
#
# If you buy store made macaroni salad, you're probably drunk and turning up on a Tuesday....or, a lousy cook. #BABYWONTYOUCOMEMYWAY?!?!?
#
# It's going to be an interesting summer when I out drink my parents lol
#
# Bitches live on twitter i swear.. 😂😂your real life must fucking suck when youre not drinking or just being a hoe
#
# Went to the beach, met up with prom weekend squad, drank hella limearitas, got high at a mansion, &amp; went on a boat w/ a guy rockin a man bun
#
# It's really unfortunate when you're newly 21 just tryin to get your first legal drink and no one card in New York
#
# Too hot already. Need WINE. Glass of white on the house with the purchase of an entree tonight only if you mention this post. #mmmwine
#
# Downloading the drunk mode app, not for being drunk but just to continuously block myself from texting people 😂
#
# Got to hear Jacco Gardner sound check for a sec, pet some kittens, eat a burrito and now drinking wine in air conditioning
#
# Yep....and it's amazing. - Drinking a Pumking by @stbcbeer @ Wilson's Pub  — http://t.co/26KRSfCzn2
#
# Shot gunned a beer for breakfast. It's going to be a glorious day 😜
#
# I'm really sorry @ussoccer_wnt for getting drunk before the game started. It's not tradition and im freaking out.
#
# Let’s get drunk. You had me there. Let’s get high. Bitch im there. You wanna get fucked up. I’m your man. Let’s get fried and fly like super
#
# House sitting for my parents. Made a good meal. Went and got ice cream on the lake. Then porch beers/wine for hours. No complaints by me.
#
# Showing up to work still drunk and high from last night &gt;&gt;&gt;&gt;&gt;&gt;
#
# You disappeared but the history is still here, that's why I try not to cry over spilt beer
#
# Home from work. I'd go out and tan but it's 93 degrees so instead I'll grab a beer and read on the couch with no pants on. 🍻
#
# It's bad but getting drunk is honestly the easiest way for someone to hear the truth .
#
# Yo if anyone needs a ride ever and im.not drunk hmu you got gas money i got keys
#
# Just called my mother she was like " I'm already on da beach eating &amp; drinking" lol lover her😭😭😂😘
#
# Neither of us wants 2 be in a relationship, but its nice to have someone there. Some1 willing to answer my drunk calls &amp; tell me everything
#
#
# 14
# ['drinking', 'only', 'and', 'the', '.', 'said', 'everyone', 'one_of', 'is', 'my', 'i', 'last', 'try', 'in', 'during', 'went', 'at', 'margarita', '@sorryimalex', 'weather', 'it_begins', '😉', 'from_the_beginning', 'session', 'a', "it_'s_been", 'spend', 'homie', 'to_celebrate', 'hour']
# Everyone's snapchat stories are so impressive compared to mine. My summer has consisted of Netflix and beer. No shame 🍻
#
# Two more hours and I'm drinking and smoking a big old that L
#
# This can be in my top everyday drinking beer. Great ... (The Session Gap [Ordinary Bitter]) http://t.co/lRoH9fbckO #photo
#
# Is you drinking tonight!
#
# Last drink
#
# I just wanna relax in an Olympic pool filled with beer today
#
# Drinking on the boat &amp; laying down is just ahhhmazing. 💜💜💜💜
#
# My mom is drinking her cheap ass margarita mix again
#
# Chill Saturday just drinking and watching ESPN
#
# The last thing I remember is drinking Absinthe 😂
#
# DRINKING, chilling the weekend #Weekend #NYC #alcohol  👌👌👌
#
# Teen drinking is very bad.............I got a fake ID though
#
# One thing made my day yesterday and it wasn't the drinking
#
# Lol one of my 35 year old black coworkers is at my crib mad drunk and lighting up.
#
# OUT HERE DRINKING THAT GREATNESS‼️‼️‼️ #DusseLifeStyle #DusseMafia samchristian88 @quin_foe… https://t.co/JFrC8GR8m6
#
# Feels a lil weird drinking and smoking infront of mom lol
#
# Couple in front of me is drinking Booze In the movies hahaha
#
# spent the day climbing rocks, sunbathing in front of the ocean, &amp; drinking whiskey. now that's what I call a successful day off.
#
# "Man, these salads will really help us reverse the damage we did with all that drinking this weekend."
# *starts drinking while eating salad*
#
# Layover. Layover. Layover. 🍷🍷🍷
#
# Buy me a drink.
#
# One of these times I'm actually going to take one of the beers the people offer me 😝 #longlonglongday
#
# Drinking 40 Oz http://t.co/ncWiQX9ph9
#
# drinking and driving has to be one of the worst things in the world.
#
# My mom questioned why we're drinking during the day.. I don't know who she is..
#
# drinking vodka and trolling nigs. the best way to spend a thursday night.
#
# It’s Thursday and it’s past noon. Thursday is one of my days off. On my off days, I start drinking at noon. You don’t get to interrupt that.
#
# Drinking is good bonding time ain't gonna lie
#
# Tonight will be the 1st time in drinking since Vegas and we're going to a open bar........😳😳😳😳
#
# Shout out to the woman that is drinking and driving in Hamlin. #StayClassy
#
# Everyone and their mom is drunk in bridesburg rn
#
#
# 60
# ['like', 'i', 'or', 'a', '.', 'to', 'never', 'say', 'want', 'best', 'my', 'and', 'but', 'sleep', 'is', 'on', 'bet', 'with', ',', 'customer_service', 'pics', 'whether', 'weeks', 'correct', 'workout', '@flippinginja', 'spin', 'fact', 'matt', 'duck']
# .@MagicTreePub &amp; Eatery has T-Shirt Tuesday with half-priced craft beer or wine pours with a VE, MT or Big TapIn shirt.
#
# Word of advice 4 snapchatters: don't JUST send vids of ur bong rips or beer at happy hour. We know u r a sad lonely drunk/stoner at 3 snaps.
#
# Or if I was a drinking I would start to drink
#
# Like I love having sex w my man while I'm drunk
#
# You will never hear me say i want a one/small glass of wine, just being honest. 🍷#ilovewine
#
# I used to get tipsy and blow my ex phone up I'm glad I'm passed that stage.
#
# I'm a simple man, all ya gotta do is put a drink in my hand
#
# need a very drunk night &amp; or 5 with my primas. With mad LQ &amp; hookah &amp; of course a banging play list @VivaLaZeny @nenibriana @TiffanyyyyyS_
#
# Hopefully I can get a pint or fif of Hennessy tonight. I already gave the heads up that I want a drank to celebrate
#
# I say we need more beer but that's just my opinion js
#
# If i keep drinking the way i do I'm never gonna get the body i want. Smh.
#
# I don't even smoke, or drink or do anything.
#
# I haven't gone out drinking and partying since spring break. Not bad lol
#
# Ive been drinking too much benadryl to go to sleep..i need it though i think too much when its time to sleep :(
#
# I like my boyfriend when his drunk lmao
#
# Like basically I drank a whole bottle of fireball alone last night 😷😳😲
#
# this is from the first time I got drunk and couldn't figure out how to take selfies http://t.co/kOyw16dvLb
#
# Gonna safely say I crushed like 84 beers last night
#
# I hate when I see someone post "never drinking again" like every fucking weekend.
#
# I need a drink thanks to tonight's episode of #GameofThrones. Excited for the season finale but why only 10 episodes per season? #HBO
#
# I might start drinking next semester just to say I lived it up to the fullest
#
# Being drunk at 1am on a Monday is what I want my life. Every single day. #OBX2015
#
# tired Sam + drunk Haily = a really deep but also pathetically hilarious conversation
#
# Drinking beer is my thing. But I don't believe in smoking. Give me some damn whiskey or cigarettes! I don't care! I smoke some but w/e!
#
# I don't know why I even bother putting away my wine glass 😊🍷
#
# I like tipping my bartenders like they're strippers when I'm drunk also!!!
#
# Also I'd like to issue a formal apology to the Internet for my drunken idiocy last night
# I'm gonna finish that bottle of wine now
#
# Why aren't my friends down to drink whenever I say so 😒😒
#
# I need a drink or three..
#
# You're the reason I'm like this but hey I like being like this 😂 it's fun, let's get drunk tomorrow too
#
#
# 79
# ['drink', 'a', 'new', 'i', 'and', 'last_night', 'ur', 'dude', 'for', 'week', 'vodka', '❤️', '.', 'dinner', 'movie', 'via', 'room', 'co', 'charging', 'the', 'kale', 'trip', 'begin_with', '👀', 'de_la', 'too_drunk', 'train', 'players', 's/o_to', 'join_us']
# #NoteToSelf Don't drink on a Monday..😣
#
# Jen tried cheering and I tried taking her drink lolol 👀
#
# I wanna go out tonight I deserve a drink
#
# a trivia place that has a Drinks Night once a week
#
# let's eat these noodles, drink these beers and dance our hearts out - madison mccoll
#
# We're going to drink every time we spot a flower crown. #GovBall2015
#
# Gin and sprite all night last night.
#
# I need a drink dealing wit all these fuckin clowns.
#
# Lying about ur age is weird stop it unless ur getting alcohol
#
# Damn I just wanna swim and drink 😓🏊🏽🍻
#
# Last time I ever drink
#
# Drink tonight or drink tonight and tomorrow night!! #MrShotsEntertainment #RefreshFridays… https://t.co/3SlzzHlCoW
#
# Sometimes you just need some fckn good ass friends, a few fckn drinks, fckn good ass music and a fckn dance floor.
#
# New grad party drinking game... drink everytime someone asks me if I have a boyfriend 🍻
#
# I just need a drink already and I'll be in a better mood 😴
#
# Tonight is the last night I drink till I lose 20 pounds... Well now 15
#
# Wish I had a bf so I could drink with !  😫🍻
# fuck it drink by myself🍺🍺🍺🍺🍺🍺
#
# I wonder if I can drink this whole bottle of absolut vodka by myself..... /:
#
# Every time I drink by myself I get in my feelings...
#
# drink every time someone makes a Kent Murphy reference
#
# Sweetie, idgf what u drink. I was making fun of these guys who drink to get fucked up...
#
# Still trying to figure out how i held that drink with 2 fingers lol. A crazy night at Cuban Petes… https://t.co/8bS4mFSMfh
#
# it's not even 11 and ur drunk and high again Lauryn
#
# since I'm done w school I need a drink.
#
# I drink cause I'm lonesome and lonesome cause I drink
#
# Bruh I can't even get a chick to take me for a drink or a movie. How the fuck these niggas got bitches proposing to em? I'm a loser😩😩😩
#
# Drink drink drink till i pass the FUCK out😏
#
# then when the chick drink got stuck in the machine dude said "my bad I forgot to charge it last night "😂😂
#
# Work Rest Drink Sleep Drink
#
# Pours a drink alone w my sick ass garlic and onion meal from out of nowhere, raises it, a toast! to me!!! B)
#
#
# 77
# ['you', 'when', 'i', 'know', 'for', 'to', 'thank_you', '.', 'but', 'water', 'ass', 'on', '😏', 'south', 'my', ',', '8', 'the', 'a', 'wearing', 'my_house', 'yay', 'will_always_support', 'rip', 'thank', 'ways', 'begging_for', 'four', 'wrote', 'publix']
# When you wanna go swimming but theres hella drunk people you don't know in the pool.
#
# It's fucked up when you drink so much that you can't even drink no more cause it could mean life or death. I need Jesus in my life. Fuck!
#
# Girl quit playing you just drunk you just saying shit
#
# When you find extra beer money for tonight😍😍😍😍😍😍
#
# I'm a little drunk on you and height on summertime 🎶
#
# I will be selling drinks if nobody sells you alcohol for Ada's party
#
# They say you only drunk call/text people when you absolutely miss them or are thinking about them.
#
# If you wanna go to the bar, drinks on us.
#
# I spoke to God today and he said you've been working a lot. You deserve a drink
#
# I really need to stop drinking ventis when i haven't eaten anything
#
# I always get sleepy when I'm on that's why I don't drink😂
#
# I make bad monetary decisions when I drink.
#
# Fireball: fun while you drink it ...worse when you feel it the next day
#
# If you drive drunk I fucking hate you.
#
# @Michael5SOS I need your help drinking Corona for a baby shower game!!! Where are you????
#
# I swear songs go faster when I've been drinking
#
# When you drunk and childish af waiting for your friends http://t.co/zrRFjitzRK
#
# You know you're in a small town when you see a driver blatantly drinking beer in his truck whilst cruising down the road
#
# @Nike rumor is you people were drunk when you designed our jerseys...
# Looks decent for a drunk job.
#
# I don't drink too much I know the bud wiser
#
# You can tell my job is rubbing off on me when I'm drinking a Bronx Pale Ale at CitiField. http://t.co/oXhxvhq7Ui
#
# ion drink , i know i cant handle my liquor 😜
#
# When you drunk af and a fight break out across the street @The_Wise_Turtle http://t.co/DSotVFjrrb
#
# When I'm broke I drink stellas, when I'm rich I drink stellas ...
#
# Day drunk into the night, want to keep you here, cause you dry my tears
#
# If you see a drunk guy piss in the street outside your apt when you sneak out for a midnight smoke you have no one to blame but yourself
#
# You know you're in for a bad day when you wake up at 1 still drunk
#
# @SPOTNEWSonIG I feel like you would know can you drink on the cta
#
# When you have your first drink all week. Shitz like crack
#
# When you have your first beer http://t.co/3sYvNokokM
#
#
# 47
# ['drunk', 'up', 'drinks', ',_nc', 'and', '#healthcare_#job', 'il', 'winery', 'weather_alert', 'with', 'in', 'gone', 'is', '@iggyazalea', 'area', 'definitely', '.', 'country', 'vote', 'i', 'understand', 'the', 'leggings', 'king', 'shoot', 'videos', 'my', 'court', 'felt', 'energy']
# Dinner, drinks with my co worker in the city!!
#
# Stevie Wonder and a bottle of wine is a tradition in my household
#
# Someone come pick me up and let's get drunk af
#
# Just taught my drunk grandma how to use YouTube 😐✊🏽😂
#
# At that find line between drunk and remembering events from tonight. Lol good times
#
# 4 cop cars for like 2 drunk people at BJs lol only Irvine
#
# Unwinding for the weekend!! #Jameson #jamo #alcohol #webedrinkin #goodtimes #goodfriends @ The One Up https://t.co/tdkASgl8ku
#
# kanyes verse in the drunk in love remix is great
#
# Shorty got drunk and instead of dancing she skipped all over the party😂
#
# 4 vodka redbulls deep and drunk dad gave me $100 🙌🏽
#
# Bout to eat good &amp; have some drinks
#
# Margaritas are my go to party drinks 😎
#
# When you're drunk and really want red lobster so you try to look up their hours.... http://t.co/GcERVN4s6S
#
# My drunk friends got a flat tire @ ihop..welllll let me go pick their asses up lol
#
# Never been sloppy drunk but alcohol is problem solving
#
# Efforts underway to raise money for two babies whose parents were killed by suspected drunk driver #KHOU http://t.co/lIWGdxbgQF
#
# DRUNK DRUNK DRUNK HARRY http://t.co/mpQWIcXMZD
#
# Not that I'm drunk now but I realize I only sleep in boxers when drunk....
#
# Game 4 enjoying some drinks and food with coworkers #GSWvsCAVS #GSvsCLE
#
# Pre #E32015 tacos and drinks with @ChrisMancil @ObiWong78 @be_austin @sledgehammer70 @dvnb
#
# If you haven't seen drunk videos of me we aren't friends
#
# Having drinks with fam 🍹 @HaleyAnn_3
#
# Drunk and watching #Chuck thanks Netflix
#
# when your drunk roommates come home and wake you up&lt;&lt;&lt;&lt;
#
# Going through my phone &amp; seeing drunk pics with strangers &gt;&gt;&gt;&gt; 😊
#
# Seafood drinks and weed
#
# it's ok to be drunk on the lake @ High Rock Lake, NC https://t.co/h4tP2B6v6m
#
# Bucket List:
#
# Play drunk Jenga with my mom. ☑️ http://t.co/r7MBY2nOX4
#
# My moms drunk and trying to philosophical 😂😂😂😂
#
# Coming home drunk. Lmao fuck it😏 @cxrmenmorxles
#
#
# 63
# ['are', '.', 'the', 'and', 'who', 'a', 'is', 'to', 'life', 'in', ',', 'having', 'for', 'begins', 'with', 'other', 'r', 'coming', "i've", 'woman', 'but', 'close', 'at', 'child', 'lovely', 'each', 'classic', 'age', 'killing', 'hugging']
# Beer league is where legends are made
#
# Having drinks and talking shop with hoteliers is fun... #NegroniWeek #negroni #baglionihotels… https://t.co/97QLuxizoP
#
# there are two drunk blackhawks fans on this train singing uplifting r&amp;b music
#
# Is it bad we are playing Jews vs nazi beer pong?😂
#
# this woman is really doing coke in a bathroom stall and drinking liquor, wow.
#
# I'm a classic ADD drunk. Hee hee. Dumb tweet. Delete in morning.
#
# *Gets tipsy*
# *Debates over the morality of the Affordable Healthcare Act for two hours with other drunk adults.*
#
# S/O to a very excited,  very drunk woman for taking our picture. @ Billy Bob's https://t.co/qzMvS5q7pZ
#
# Thank goodness alcohol is NOT an acne trigger 💃🏽💃🏽💃🏽🙏. Unless you are too drunk to do your… https://t.co/NLtYz6Rf5D
#
# It could be the beer or that I'm on vacation.  But can't help having a smile on my face being back in the U.S :)
#
# Me and my cousin are drinking like its our job and watching bridesmaids. #whatislife
#
# Come get drunk with me and let's talk about life while we at it
#
# Life hack: warm beer is gross. Stay away from it, kids.
#
# Cheers to the cop who just gave us a ticket but told us to keep drinking #shoutout
#
# Just impressed some of my fellow interns with my beer pong skills. Temple has taught me well.
#
# Valume &amp; beer r good people to to relax with at night.
#
# I'm at that awkward stage where half of my friends have babies and the other half are too drunk to even find their phones.
#
# Currently arguing with my boss over who had the better beer tonight.. Landshark for the win #webothhaveworkat8
#
# Burgers, beer, basketball, and friends. 😍😋🍻🏀 #lifeisgood #earlyweekend
#
# Only thing exes are good for are lessons and drunk calls
#
# Wife and kids are gone tonight so what am I excited about? Getting a #steak and #craftbeer at @WFMphoenix and having a quiet evening!
#
# I pop champagne with who I'm closest too.
#
# MR. MAC IS AT MY GRAD PARTY AND HE'S DRINKING AHAHAHAHAHAHAHA CLASSIC
#
# no more partying and drinking for me for awhile 😇😅.
#
# @TimGettys where are you and why aren't we having a drink?
#
# I'd rather use my dog's tail to mix my drink than drink a Bud Light Mixx Tail
#
# who got a pool i can drunkenly swim in?
#
# considering going out and drinking by myself since yous are all boring and wanna sit in and stair at walls
#
# To all the guys who deliver beer in Houston. U ain't getting paid shit AND NOW u gonna work your ass off this weekend restocking. #prayers
#
# Who is partying with us this weekend!!!!! #mexicanmoonshine #circusmexicus2015 @ Tops Liquors https://t.co/EOiEmCOMYM
#
#
# 87
# ['all', 'time', 'the', '.', 'ny', 'and', 'to', 'in', 'is', 'for', '#newyork_,', 'at', 'my', 'i', 'men', 'birthday', 'rain', 'nicki', 'dale', 'ima', 'health', ',', '#sundayfunday', 'publicly', 'strong', 'agree', 'add', 'career', 'tears', 'ice_cream']
# Hi guys how are you it's 11PM and I just got home from work and all my friends are drunk at @theearlynov so like time to be #emo 😿
#
# Remember that time we... Oh wait you were blackout drunk. @TheDrunkStory @WTFConfesslon #drunk #BlackOutDay #whathappenedMissSimone #tbt
#
# My dog ate all of my penne alla vodka before I got to and I've never been so upset in my life
#
# That time I finished every drink on the menu at Suds Mcguire in on sitting....
#
# #ALLinCLE
#
# I'm hungover half the time and drunk the  other half
#
# Had 8 beers this afternoon. It might be time for a nap
#
# Yeah I still drink about him all the time🎶🎶
#
# When you're the only one under 21 in the office and all your coworkers start drinking at 4 and you're just sitting there like😕
#
# Dads birthday I'll drink to that ...
#
# All the beer. All of it. @ The Pint House https://t.co/2KRkkn4FTf
#
# My beer goggles were strong last night.
#
# It's about time to start drinking lol
#
# Time to drink away the stress of working retail 🍻
#
# Drunk munchies are at an all time high
#
# I swear only time I drink more than 1 drink is when I am at home.
#
# I took 56 bars all in one month nigga and I'm still drankin
#
# mine and Sarah's drunk asses lastnight 😝 http://t.co/zwg4fgJCkK
#
# Why can't I just experience a cold beer and my hand and my toes in white sand ONE TIME IN MY LIFE
#
# Yo I'm Wiping The Tears From My Eyes Right Now
# I'm So Fucking Drunk
# All Because Of You Baby
#
# Everydaayy I spend my time, drinking wine, feeeling fine.
#
# Monday night drinking. @ Brandy Library https://t.co/BeMeyTvkxA
#
# All we do is fuck, drink, and sleep.
#
# It amazes me how all some people wanna do is drink all the damn time
#
# People already drink after work Chicago, this is just providing an incentive like pretty much all states do.
#
# Everyday I spend my time drinking Wine living fine🎤👼🍷
#
# Just wanna go out for drinks and crawfish soon...
#
# I'm half straight edge cause all I do is drink :)
#
# I get the shakes from drinking Ima have Parkinson's by the time I'm 24
#
# that feeling when you're a lil drunk all cozy in bed and shit &gt;&gt;&gt;&gt;
#
# Now time for some overpriced beer #LAX
#
#
# 26
# ['just', 'some', 'and', 'i', 'a', 'with', 'video', 'black', 'every', 'on', '.', 'my', 'for', 'should_be', 'in', 'starbucks', 'to', 'at', 'the', 'system', 'jack', 'takes', 'everywhere', 'great_day', 'asked', 'quit', 'location', 'of…', 'director', 'my_family']
# "I need a drink because I'm upset about some punctuation" is something I could say at the end of every. single. day.
#
# Celebrating with a nice glass of Meritage wine from jeffersonvineyards and grilling some meat while… https://t.co/cCBOYRjdw8
#
# I want some cold beers, some blunts &amp; good company
#
# I drink liquor and eat ice cream...Sooooo whatttt
#
# I need a public chicken tender sub rn
#
# just getting my summer time on with my best friend 💕☀️ @ drink up 🍻 https://t.co/gLT2eSwidv
#
# I need a drink and some tequila with youuuu
#
# Now that I'm drunk, Netflix and food jus sound like a good night
#
# Some drunk tried fighting me in front of Popeye's last night lmao
#
# Want a nice juicy steak and some wine
#
# That one police officer from the city of #McKinney in that infamous video was drunk off power
#
# Beerfest with @lilr0bin and @Bazooka_Dave. My night just got better!
#
# Some teenagers get drunk and party at 3:30 but I stay up and watch greys anatomy at 3:30
#
# I need to re first fuck some of these females.... I hate how some feen for me, but some caught me on a bad day n shii lol
#
# I just want some good h____ and a nice cold beer lol
#
# At the liquor store with my dad I almost told him to get me some vodka 😂😂
#
# Rum and coke and some wine with my Lulu
#
# Gonna drink a little and watch some movies tonight
#
# I don't even attract boys anymore I attract drunk old ladies
#
# Just got drunk in a matter of 5 minutes shit
#
# so cool hearing "Everywhere I go" by @NewPolitics on a commercial! Think it was one for beer or something...a beverage
#
# Beer pizza and finishing @OITNB ! #turnup
#
# I'm really not human no hangover and ready to drink some more
#
# Room tempature IPAs ain't even bad. They taste pretty good. Ima start drinking all my IPAs like that.
#
# Craving some hot wings and an ice cold beer
#
# I dont even drink, I just be on that drank, I just be on that dank, and wide awake like I ain't
#
# some drunk dude is just passed out on the beach in front of my camper 😂
#
# I need dope as girl friends that down to shave some fun and drinks! 🍻 need new friends!
#
# my parents literally got up and drank a Bloody Mary wow go my family
#
# Just a perfect day, drink beer on the beach... you just keep me hanging on #summer #LosAngeles… https://t.co/mzBRPuappY
#
#
# 90
# ['of', 'the', 'out', '.', '#retail_#job', 'in', 'n', 'though', 'and', 'to', 'little', 'sc', 'my', 'na', 'banging', 'view', 'lake', 'happen', ',', "couldn't", ':_assistant', 'such', 'at', 'tour', 'thx', 'drunk_ass', 'proud', 'bugging', 'alright', 'store_manager']
# @AKGrin does a great job of drinking beer in this. http://t.co/fBj3zlyS8D
#
# I get out of work at 12:30 and need the world's biggest drink. Who's interested?
#
# I wanna be drunk when I wake up, on the right side of the wrong bed http://t.co/HtvwqHVaKl
#
# Status : drinking wine straight out of the bottle
#
# Ice House Inn has a great selection of craft beer on tap and big glasses to drink it in. Check out the Beach @BeachShack330 out back!
#
# Dear friends,
# Bought more alcohol and party supplies and food that I shouldnt have to buy any drinks while out for the rest of the summer.
#
# This has been one of the most trying days I'm in real tears and in need of a drink
#
# Wine on top of wine on top of wine and on top of scotch! Crazy wine bar in Beverly Hills. @ Wally's… https://t.co/P3Pw592KVZ
#
# Mother of Jesus, I'm still drunk. I cannot do tequila again
#
# finish my final at 10 then Jordan is coming over with some good drinks n good music n ima start packing
# best way 2 spend a saturday night
#
# Ima be under the influence of drugs and alcohol 99.9 % of the time
#
# Cold ass beer hits the spot in this heat🍺☀️
#
# Drunk conversation of the night: first time sex and past relationships.
#
# @8thWonderBrew I'm drinking Big Flats out of one of your awesome pint glasses. NOT AS GOOD.
#
# @bchandra_3: My friends peer pressure the living shit out of me to get me to drink every damn night!!! Alcohol is bad for the soul.
#
# The biggest issue currently facing me in life... I set my beer down out of arms reach
#
# I wanna be drunk when I wake up, on the right side of the wrong bed
#
# The city of Cleveland and Dan Gilbert owe @matthewdelly two steak dinners and a keg of fresh beer. #ALLinCLE
#
# I've been drinking though so I could just be talking out my ass
#
# Pabst Blue Ribbon: official beer of the #NBAFinals2015
#
# Cheapest pride tab evar! Paid $7.50, received a minimum of $25 of drinks.
#
# The best part of Saturday is watching drunk girls struggle on the streets of LA
#
# Truth or dare with a bunch of drunks at e3 in the morning is the best/worst idea
#
# Very enthusiastically chugging the last bit of my beer only to spit it out at the sight of a fly.
#
# Nothing like a 7 hour airplane delay to recover from two days of drinking in 107 degree heat. Finally east coast bound though 🙌🏼
#
# I have been out of wine for days!!! Holy crap
#
# Im really getting sick of only being needed in the middle of the night when you're too drunk to go home or when the cops show up...
#
# So sick of the ratchets that come to Bww get drunk and grow up all over the place
#
# Drank out of a slurpee thing last night bc no one else had enough balls too
#
# Draw the marrow out of life's bones and drink deeply
#
#
# 43
# ['"', 'wine', 'could', 'is', 'a', 'maybe', 'my_mom', 'literally', 'the', 'i', 'sales_and_marketing', 'cute', 'my', 'with', 'engine', 'my_phone', '".', 'new_horizons', 'legal', 'totally', 'die', 'af', 'but', 'for', 'wall', 'soup', '❤', '"!', 'the_only_thing', 'along']
# Idea: a bar specializing in craft beer called "Deja Brew"
#
# "Do you have experience with Wine or Texas Draft beer?"
#
# In deep panicking thought "Elena. Senior Year Never Happened.. Be cool."
#
# NO SIR.
#
# Whatever were drinking right now got me like ayyy
#
# Nice meal and a good wine, definition of a good time
#
# "When I get drunk I give my self hair cuts" guess whoooo
#
# "Turn that frown upside down beautiful"  -random drunk guy 😂
#
# My mom is so drunk she let me take the wine bottle with me 😭😭😭😭😭💞
#
# "Hannah's drunk!" Hannah:"I'm actually not I'm just an asshole"
#
# "Is anyone not drinking?"
# *silence*
# "Well that's good to hear"
#
# "When she's super drunk I'm gonna hit on her"
#
# "If I stop drinking all at once, I'm afraid the cumulative hangover will kill me" -Sterling Archer @ArcherFX @ArcherQuote #wisdom #jealous
#
# Play some "beer in Mexico" and other throwback Kenny!!! @983NashIcon
#
# Then you get that "you drink too much lecture"
#
# "From Beer to Fraternity"
#
# #MakeAMovieLessRomantic
#
# I once recommended @DougStanhope to (an apparently rather sensitive) pal. She said "I needed help" for "finding that drunk lunatic" funny.
#
# "I'm only driving drunk cuz that bitch drove me to drink"
#
# I wish we could get rid of legal alcohol.
#
# "remember when we all got wasted at chris's"
# alex we each drank one beer...
#
# *playing bp "I thought I was playing basketball for a second" -some drunk guy at my house
#
# "OMG we are going to get so drunk together" the step dad talking about when I turn 21
#
# "I'm not drunk I just did twenty jumping jacks" 😂😂
#
# "@landon_lombardi: The LIRR has warnings about not drinking on the train for the Puerto Rican day parade" God I hate my ppl
#
# all Dakota has said this morning: "I want jojo" and "I'm never drinking again"
#
# "If you need me the rest of the day, I'll be drunk"
#
# "Let me charge my beer real quick bro"
#
# "I thought this was the 3rd like Im drunk"
#
# "Everyday I spend my time drinking wine feeling fine"
#
# "I'm the DDDD. Designated drunk duramax driver. "
#
# HELLLL MF YEA! RT @jaaay__xo: I hate when guys tell me "drinking isn't cute" like okkkkk bitch I'm already cute I'm trynna get turnt so bye
#
# Wish I could drink or smoke
#
#
# 84
# [',', '.', 'oh', 'did', 'and', 'read', 'until', '2015', '#columbus_,', '#craftbeer', 'my', 'met', '|_#columbus', 'with', 'save', 'drinkin', 't', 'death', 'challenging', 'i', 'at', 'columbus', '|_ohiohealth', 'canada', 'the', 'imaging', 'fruit', 'drinking_again', 'fav', 'in']
# Listening to whiskey lullaby, already finished half bottle of Yukon, quarter through Jim. Fuck
#
# oh, you be smoking drinking lean and popping xans, huh?
#
# About last night, good vibes with friends. Drinks, Dinner and Pool. 👊🍻🇺🇸❤️ @ GYM Sportsbar https://t.co/Jrewp8ntfz
#
# Cheap pizza, beer, and video games? Sign me up.
#
# Beach, beer, hockey, and at some point, pizza. Todays been a damn good day.
#
# Literally I am never drinking again
#
# I promise you, I'm not a drunk or an alcoholic @ Lyell-Otis, Rochester, New York https://t.co/45tj2YHlKO
#
# Feel like I'm in an old western movie cus im drinkin warm whiskey, lemon juice and honey in order to stop being sick! #cowboy #sick
#
# Why would my mom ever come in my room jump on my bed and wake me up , asking if I was drinking, smoking, or having sex last night 😡😡 Pissed
#
# You guys, if your profile says you only drink on special occasions, probably not gonna work as I only don't drink on special occasions.
#
# "I'm gonna get in the bar chug so many beers, rip some shots, poor some champagne, college Rory's coming out tonight"
#
# I don't particularly enjoy drinking, singing, dancing, or people. So I'd fit right in at this party. #THEWICKERMAN #DriveInMob
#
# 1, 2, 3 drink
# 1, 2, 3 drink
# 1, 2, 3 drink
# 1, 2, 3 drink
# 1, 2, 3 drink
#
# Tripping out on the fact that I've had nothing but beers and a few cup of noodles today, literally
#
# Good beer, good friends, and nothing but good vibes.
#
# everyday I spend my time, drinking wine, feeling fine, waiting here to find the sign that I can understand, yes I am.
#
# some beer, Chinese food, and #NBAFinals and cubs game when commercial appear que mas quiero
#
# First week of summer has been complete, busy, expensive, hot, rainy, fun, loud, drunk, fast, bullshittttttttt
#
# Goodbye Italy, Hello, L.A.! I'm done drinking wine for a little spell.
#
# Get up, to go work, go to the gym, get home, crack a beer, put on WWE network, repeat.
#
# Omg I am sooootired. NOKoreanFood2day, orderedExquisiteIndian2myelevator instead. I start work 2morrow, late night club hrs, cant drink. LOL
#
# So lets just stay in the moment, smoke some weed, drink some wine, reminisce talk some shit, forever young is in your mind 🎶🎶🎶
#
# First time going too a bar, needless to say, I'm drunk.
#
# Last night=hella of a concert,mud pit, random chick tryna kiss me, sketchy dude offering me weed, and a chick handing me her beer and leavin
#
# Off at 5, drunk at 6. Good start to the weekend.
#
# As my favorite rapper would say, "YEAH!!!"
#
# I really wanna go to the beach , smoke , eat, get drunk, watch the water type shit with my nigga type shit,😐
#
# I enjoy being single. Got my dog, alcohol, I'm set. 😌
#
# Went to the bar last night, drank a good share of beer, and only spent 10 dollars.. #2dollarPBR
#
# Right now what I need is an inspirational, feel good movie....any suggestions?? Oh, and wine...I really need wine! RED!🍷 Tnx in advance! 😉
#
# This picture perfectly describes this weekend: blurry, drunk, sandy, happy. @ Hagar Shore Beach https://t.co/MM3Mf0rANq
#
#
# 86
# ['drinking_a', 'lounge', 'first', 'alert', '😒', 'ipa_by', 'ale_by', 'kid', 'dead', 'con', 'many', 'law', '😈', 'small', 'brewing_co', 'weed', 'cheese', 'this_guy', 'management', 'lo', 'children', 'sun', 'success', 'at', 'su', "can't_believe", 'cole', '#newportbeach_,', '@_voltage', 'beginning_of']
# #PBW2015 - Drinking a Berliner Weisse by @SCBrewingCo at @barrenhilltav  — http://t.co/oXhqdkLANa
#
# Drinking a Bull Island by @wabashbrewing @ Wabash Brewing — http://t.co/7YLLfuEzD5
#
# Drinking a Green Diamonds by @OtherHalfNYC @ Local 44 — http://t.co/82eS2rUbHO
#
# Drinking a Jalapeño Pale Ale by @BirdsongBrewing at @peculiarrabbit — http://t.co/e1LshTGSo0
#
# Drinking a Wolf Among Weeds by @goldenroadbrew at @flannys_tempe — http://t.co/ldHRPFtnQx
#
# Drinking a Beer Hates Astronauts by @halfacrebeer @ Chalmun's Biergarten — http://t.co/Aj7XqGCVwA
#
# Drinking a Popcorn Pilsner by @SunKingBrewing at @bwwings — http://t.co/1HihdQVzmo
#
# Drinking a Rodenbach Grand Cru by @rodenbachbeer at @ncbeertemple — http://t.co/p5ouI3Hyog
#
# Drinking a Staycation by @karbachbrewing @ TurnCock Patio — http://t.co/LOc6uXlQ70
#
# Drinking a Brevity Wit by @DruthersBrewing at @druthersbrewing — http://t.co/Bjb2ARvDhB #photo
#
# Drinking a Hibiscus Gose by @Boulevard_Beer @ Flying Saucer Draught Emporium — http://t.co/c92tsbZ3A9
#
# Drinking a Greenhouse IPA (Batch #20) by @hopsandgrain @ CJ's Beer Garden — http://t.co/0Wa51utUDu
#
# Drinking a Hoptimum by @SierraNevada at @quaffonbtown — http://t.co/YLbcXrghar
#
# Drinking a Sir Dunkle Crisp Dark Lager by @BerghoffBeer @ United Airlines Employee Cafeteria — http://t.co/KnJIpNwls6
#
# Drinking an Anchor Saison Spring Ale by @AnchorBrewing at @fibbermagees — http://t.co/zQgfm69WPg
#
# Drinking a Hop Sun by @stbcbeer @ Monty's Krown — http://t.co/lgwUu7mM6q
#
# Drinking a Parallax Vanilla Porter by Planetary Brewing Company  at @shallos — http://t.co/56XzMcodLo
#
# Drinking a Moon Man by @newglarusbeer @ Limestone Development — http://t.co/F8lFM2NogP
#
# Drinking a Red Fish by @jerseyfreshale at @nycparks — http://t.co/FJfnvLVcoq #photo
#
# Drinking a Nirvana IPA by @BreweryOmmegang at @hopshopbk — http://t.co/8wVOaBkntP
#
# Drinking a Proverbial Mind Spread by @ShortsBrewing at @shortsbrewing — http://t.co/8kfSsrWhzy
#
# Drinking a Single-Wide I.P.A. by @Boulevard_Beer @ Lake Travis — http://t.co/Qeh3SnFOKm
#
# Drinking a Swami's IPA by @pizzaportbeer at @caseysdtla — http://t.co/RUnSy3vZ1C #photo
#
# Drinking a Stone Cali-Belgique IPA by @StoneBrewingCo at @rattlenhumbarny — http://t.co/NAjnkJBhLL
#
# Drinking a Honker's Ale by @GooseIsland @ Taberna del Tequila — http://t.co/ekwL19xHPb #photo
#
# Drinking a Lift Off IPA® by @DaredevilBeer @ Daredevil Brewing Co — http://t.co/CvmxeWsoDz #photo
#
# Drinking a Long Day Lager by @redharebrewing at @thewingtaphouse — http://t.co/lwBXAv3zBX
#
# Drinking a Prohibition Ale by @SpeakeasyBeer @ Crafty's Tap Room — http://t.co/0sTA3nEcUY
#
# Drinking a Fist Of Karma Brown Ale by @DruthersBrewing at @druthersbrewing — http://t.co/RoQn4slaUp #photo
#
# Drinking  The Village Reserve by @ShortsBrewing @ Calimax Market — http://t.co/awkcKWfAEU
#
#
# 40
# ['me', 'and', 'to', '#chicago', 'made', 'my', 'someone', 'yeah', 'hard', 'on', 'at', 'celebrating', 'visit', 'i', 'answer', '.', 'sell', 'instagram', 'the_same_time', 'bday', 'anybody', '💗', 'is', 'stars', 'a', 'r_u', 'jesus_christ', 'wants_to', 'yr', '🌈']
# I thought maybe you'd stay and try to out drink me
#
# All these sake's and drinks have me feeling right!
#
# according to layna, it's still my MF'in bday 🎈somebody beer me.
#
# I'm basically made of alcohol and disappointment
#
# when someone tells me I should stop drinking so much http://t.co/O0mLEFBcU7
#
# Thank god Nikko is drunk and won't remember me twerking
#
# @84TigersDetroit so I just showed my shirt and my coozie to a couple of fellow tigers fans and it got me a beer! #finefolks #nicearea
#
# Not being able to drink is the only thing that motivates me hahaha
#
# When at a family dinner it's essential to order 2 alcoholic drinks at once
#
# All of my friends are drinking tonight and I'm just like me too.. #SparklingWaterBetch http://t.co/L4ZMNuuXpX
#
# Had to jack a blunt from one of these lames at my house, they all drunk af idc 😂😂😂😂
#
# I got in trouble for posting those stories of my mom all drunk on my sc story😂
#
# Some girls just walked up to me drunk af like "You youuu youuuu... Are the most beautiful person I've seen in my life"
#
# My days been made 😏
#
# *gets arrested*
# Me: I'm never doing anything illegal again
# *2 days later*
# My friend: wanna drink?
# Me: hell to the fuck yeah
#
# Me an Melissa went from talking about love to get drunk 😂
#
# I just think everyone wants someone to text when they're drunk 👐🏽😂 #maiyaquotes #lifegoals
#
# goes out to buy beer and ginger ale at the deli thats 2 min away and gets stopped by 3 crazy people. got me feeling like frodo
#
# Jesus it is hard to drunk screenshot on this phone wtf.
#
# Yup and then my beer exploded all over me and my luggage. So that's my life.
#
# Nate drunk as fuck http://t.co/gykOzno3nr
#
# @ceniamtz: Happy Birthday to the homegirl Grace 💕💕♊️ 😘 drink up that cheap Europe wine for me 😉 #cheers @grace_reuter
#
# Hard Ü wtf? Go home hardwell you're drunk
#
# So vodka street charged my card 2 days ago I must have been super hammered and somehow made it back to Houston
#
# Don't get me started, I've had too much to drink.
#
# Drinking is so insanely unattractive to me
#
# Someone get some wine and let's have Sunday dinner
#
# so who is going to the parade with me, drinks on me!?
#
# I dropped a drink today and someone started clapping why is that necessary
#
# So bum me a cigarette, buy me a beer till I'm happy to be here.
#
# Every time my bro comes to visit I have to prepare myself to drink a lot and not get much sleep haha
#
#
# 23
# ['tonight', 'the', 'at', 'with', 'amazing', '@…', '.', 'point', 'for', 'on', "can't_wait_to", 'and', 'red', 'rock', 'is', 'in', 'my', 'heart', 'album', '💜', 'secret', 'truly', '😢', 'a_glass_of', 'tart', 'to', '#sffs15', '#scottsdale', '❤️❤️❤️', 'liberty']
# ive had more drunk texts and than sober texts today thats cool too
#
# plan on beating Tyler and Forrest at beer pong again tonight 😎 @HayleyBooooo
#
# @Djais Fri HH 5P Free Buffet No Cover til 9P $2.50 beers $4.50 Drinks 2nite @DJRizNyc Print/show RIMI pass free drink http://t.co/rPpFYydgcO
#
# Henny shall be drank tonight with pineapple juice
#
# They probably see me and think "what is this drunk bitch gonna say to us tonight"
#
# If I have a glass of wine before bed, then everything will be fine..to much on my mind tonight 🍷😴
#
# #NBAFinals game 2 NOW at the haus. Drink... (er) WATCH with us tonight!
#
# Can't wait to be in Vegas this weekend with my love❤️😍 @AmandaLeeCase
#
# #NBA #Finals good #tacos good #drink good #hookah tonight at @epic22lounge best Tuesday groove in the… https://t.co/XRGTaJXghY
#
# Just want to be at seaside with a beer already
#
# Had the best time with @chelseamento tonight! @AvalonInsider #beer #musix #shopping  #bocado #girlsnightout
#
# Ok...bathroom &amp; beer break. More #iHeartPoolParty moments away on @WCCBCharlotte. Turn it on!
#
# What can I say, drunk texts are the best texts http://t.co/wiQ0UlrMgD
#
# ...
#
# @TheDrewLynch Oct 2003 at a red light a drunk man hit me then ran leaving $600,000+medical and permanent spinal damage.
# DOIN IT DISABLED
#
# When a beers nice n cold http://t.co/GhizjSPlZS
#
# The only thing better than drinking beer and watching sports is drinking beer and doing anything else
#
# Melissa McCarthy embraces being busy http://t.co/7If50OfGra via @NewsRepublic
#
# v glad
#
# for margaritas
#
#
# 62
# ['by', 'too', 'thanks', 'were', 'let', 'put', 'please', '-_&gt;', 'the', 'on', 'at_least', 'sweet', '.', 'of_course', 'for', 'send', 'putting', 'radio', 'my', 'to', 'in', 'sounds', 'my_face', '@madisonellebeer', 'course', 'schools', 'creek', 'posts', 'sugar', 'an_awesome']
# Drinking a DFPF by @Jwbrewing @ Moon Base Zeta — http://t.co/KcdodHEssb
#
# *the single friend who drinks too much* a memoir by me
#
# Drinking an Ananda by @wiseacrebrew @ Yogi Bear Jellystone Campground — http://t.co/pGhSznqkqg
#
# He put that right in my face knowing I can't drink that😂
#
# Stop by the Farm Stand for an ice cold draft beer before Bella Fleck @CornerstoneArts , 3$ pint.  #summerfun
#
# Let the weekend begin...                            @Hangar24Brewery                             #bettyipa http://t.co/X9V7hTi3JP
#
# Drinking a Galaxy by Anchorage Brewing Company @ Lane Creek Golf Course — http://t.co/nfIMgPpDdy
#
#
# 67
# ['😂', 'had', '!_read', 'about_our_latest_#job', "we're_#hiring", 'opening_here_:', 'house', 'yall', '😂😂😂', 'summer', 'opening_here', 'sober', 'actually', 'around', 'crazy', '#engineering', 'hell', 'i', 'obama', 'phone', 'race', 'services', 'dance', 'songs', 'cry', 'store_sales', 'my_sister', ':_electronic', 'smile', 'internet']
# because sometimes you just need to get drunk &amp; dance around the house singing Beyoncé all day l http://t.co/Nzo8yPVm03
#
# The smell of stale beer reminds me of every hangover I've ever had
#
# Moving into the new house and mom goes 'you know what I can see happening, getting drunk and you sliding down these stairs' 😂
#
# Sorry I was sober! Got yall next time for sure
#
# my mom said my sister never driked till that one night she came home drunk asf 😂
#
# Dance, dance, dance the night away...#pbw2015 - Drinking a B.D.G. (Brunch Dinner Grub) at @perchpub - http://t.co/9KoOUVoYR4
#
# I'm at McGillin's Olde Ale House in Philadelphia, PA https://t.co/CnamhJUwpX
#
#
# 68
# ['girl', 'right_now', '+', 'family', 'remember', 'enough', ';_)', 'tuesday', 'with', '=', 'my', 'plus', 'shop', 'events', '😇', '.', 'so_happy', 'bringing_back', 'moving', 'track', 'training', 'people_who', 'needs_to', 'nj_teachers', 'is', '!_#thewholetruth', 'public_workers_rally_against', 'heaven', 'for', 'gonzalez']
# The only thing worse than being uncontrollably drunk with family friends is being uncontrollably sober with family friends
#
# I wish @AlexZiegenfus was with me right now
#
# An iced cold beer would be amazing right now
#
# when your family lets u drink at the family party 😎😎😎😎😎😎😎😎😎😎😎😎😎😎😎😎😎😎😎😎😎😎😎
#
# All kinds of pissed was supposed to go out drinking with my sisters tonight, instead lilsis deadbeat be ruined the night and we watching tv
#
# Farewell drinks with my girl @LiesaPiesha #goodbyesaresad #iwillhavetovisitphilly #friends @ Franklin… https://t.co/IOBm5TaREx
#
# My girl the realest person on my team if it ain't her 🌵yall
#
#
# 72
# ['them', 'male', 'since', 'the', 'thanks_for', 'says', 'friday', 'follow', 'dog', 'and', 'too_much', 'top', 'my_friends', 'welcome', 'bitches', 'k', ':_-)', 'calling', 'g', 'on', '.', '@enrique305_please', 'issue', 'ga', 'cali', 'my_fav', 'annoying', 'horrible', 'article', 'u_r']
# "I have wined and dined with kings and queens...and I've slept in alleys and dined on pork and beans." #RIPDustyRhodes
#
# Considering the majority of my friends are on cruise ship drunk it's likely at least one of them might fall off
#
# Drinking game: Drink every time Joe Buck says "Feskew" during the #USOpen coverage.
#
# Drank a little too much Hennessy at the club last night. #wavy
#
# And finally the hero, the shadow boxer. ivymix leyendabk #cocktail #booze #drink #tuesday #thirsty… https://t.co/UqZFqIa1xV
#
# @MKTGRepublic Thanks for the FAV! http://t.co/wxVjUJdYpi for direct marketing success http://t.co/oJUeJudC5v
#
# #Saturday #booze #1WTC @ New York by Gehry https://t.co/8ke2T9U8VU
#
#
# 80
# ['we', 'there', "he_'s", 'sorry', 'soon', 'in', 'shirt', 'words', 'brewing_company', 'jewelry', 'needs', '.', 'david', '@jogginsteadyqh', 'keeps', 'mexican', 'he_has', 'keeping', 'epic', 'medical', '🔥', 'nation', 'a_couple', 'check_it', 'miller', 'gays', 'a', 'the_truth', 'horse', '💚']
# Pregaming and we have no idea what we are doing tonight. @JoNobles
#
# drinking like there's a message in a bottle🎶🎶
#
# He's funny af though when he's drunk
#
# Never understood why niccaz drink lean
#
# we did @bre_bastian 's math placement test drunk tonight and passed... Don't ask us how  but we did it😅
#
# @Nicolo_Perry im bringin a beer bong saturday....
#
# We drank beer for no reason last night and we had fun doing it😂 @KungFuPuma http://t.co/F24eI0oPBA
#
#
# 85
# ['part_time', 'done', 'give', 'event_specialist', 'bought', '[', 'on', 'cut', ']', '.', 'with', 'reading', 'brother', '😜', 'touch', 'dan', 'research', 'publish', 'five', 'jalen', 'tryna', 'mostly', 'good_times', 'blog', '25', 'wholesale', 'likes', 'yellow', '@alene721_@seedywumps', 'traffic']
# #fruitflies on #fleek #airportdrinkingestablishments
#
# Wow my cast mates bought me five beers.
#
# Great weekend with this beautiful women. @ Houston Beer Fest https://t.co/msawym6CAj
#
# #nintendo #mariobros #retro #scottsdale #beerpalooza #az @ Scottsdale Beer Palooza https://t.co/Y8x1LKRwWh
#
# Experiencing my first hangover and me no likey. My favorite drink's betrayed me😩 READY 2 TURN TF UP 2NITE THO LOL @julietweybret @mxcardona_
#
# Creating success in cities by reimagining the civic commons #KnightCities http://t.co/WI73xeUOFX @ccoletta @CityObs @knightfdn
#
# Clay bought a snake. #cryinginside 😭😭
#
#
# 93
# ['no', 'man', '.', 'real', 'yo', 'gotta', 'living', 'q', 'sr', 'tea', 'professional', 'wins', 'crying', 'vale', 'is', 'u.s.', 'prob', 'for', 'spirit', 'award', 'given', 'ice', 'hops', 'grand', 'project_engineer', 'the', 'leading', ',', 'results', 'claim']
# Drinking an Alabama Pale Ale (APA) by @railyardbrewco at @firebirdsgrill — http://t.co/v3MMxkOjz3 #photo
#
# good weed &amp; cold drinks nigga that's the recipe
#
# No drunks.. No weed smokers.
#
# Try to imagine if #NBA had not adopted 3-point shot. No #StephCurry tonight. No #KlayThompson
#
# I need tea for my whiskey 😪
#
# Tonight. #housemusic #Phoenix
# No Cover.
# No bottle service.
# No attitudes.
# No bullshit.
# Just Great… https://t.co/1ahgkjrB3T
#
# Man down, man down! #ineedabeer! http://t.co/ztYG8kGWtn
#
#
# 1
# ['singing', 'i_am', 'things', '😊', 'myself', 'en', 'republican', '.', 'instead_of', 'los', 'si', 'ready', '🍻', 'thursday', 'three', 'le', 'shower', 'goals', 'caught', 'queen', '100', 'with', '11', 'featuring', 'my', 'puberty', 'human', 'talents', 'finished', 'solutions']
# I am not the pioneer of drunk shopping im sure but I am definitely an advocate/avid participant
#
# The fact imma have three bitches with tonight while we all drunk means goals are accomplished
#
# May or may not be a bit drunk
#
# things that have never been cute: getting sloppy drunk in public. though you may not remember, everyone else will. ☝🏼️🚫
#
# Last weekend @ Chipotle. 🇺🇸 I miss this place. #nyc #NewYork #chipotle #food #margarita @ Chipotle https://t.co/y2TwiyAyaI
#
# @ABC7Gisela Have my Heisenberg Vodka ordered
#
#
# 15
# ['back', '....', 'show', 'hey', 'ok', 'to', "y'all", 'hear', 'the_beginning', 'in', 'a_lot', 'the…', 'the', 'film', 'my', 'throw', 'meant', 'write', 'tix', 'is', 'teacher', 'i', 'thank_u', 'force', "i've_ever", 'greece', 'singin', 'but', 'a_joke', 'for']
# @Muhammad_Holly   Hey Holly!  Let's grab a beer soon!!!!
#
# Thank u to the 12 cosmos I drank last night
#
# @nottusjosh hey stop I'm to drunk for this shit
#
# Happy birthday to my brother @mattdsimon1 ! Miss ya mane! When I get home lets throw some beer back and fish!
#
# Ok so my parents are gone starting July 18th and I'm getting drunk w every person I've ever talked to on twitter
#
# I would like to apologize in advance.... cuz I been DRANKIN!! Scratch that.... Liquor run ....
#
#
# 39
# ['party', 'bitch', 'happy', 'in_public', 'saw', 'anyone', 'a', 'weird', 'gay_marriage', 'community', 'problem', 'with', 'representative', 'must_be', 'the', 'kill', 'short', 'at', '.', 'rich', 'pregame', 'facts', 'is', 'forgot', 'ms', 'kept', 'according_to', 'to', 'i_forgot', 'evil']
# @kennis_amy just witnesa ed me drunk AF!!!
#
# #SNL4fun Dumb Girl From Party is just Drunk Uncle with slightly altered script and a bra........
#
# I was happy in the haze of a drunken hour but heaven knows I'm miserable now
#
# Now im getting a pint n facing that shit ....
#
# Having a drink with my pops on 39th. I used to run around this bitch had my first kiss and fight. Shittz crazy I guess they do grow up fast
#
# Anyone at the beer tent
#
#
# 50
# [',_il', 'really', 'gay', 'in_chicago', 'i_thought', 'monday', 'robert_half', 'x', 'at', 'going_on', 'fire', '|_#chicago', 'margaritas', 'tweets', 'my_friend', 'commercial', 'buggin', 'chris_brown', 'encouraging', 'whole_foods', 'boo', 'catch', 'turn_up', 'idk_why', 'how_many', 'finance_&amp;', '💘', 'drunks', 'pleasure', 'with']
# Fiesta cheap I thought they was gon have real mariachis these niggas look like drunks lmfao
#
# Lunchskis // beer x tacos @ Tallboy Taco https://t.co/yqvJnzTC5q
#
# Gon pour this wine in your memory
#
# Hawks! (at @TheBeerBistro in Chicago, IL) https://t.co/HQskSn4gbZ
#
# @TallTalesandSL at @BootAndSaddle !! http://t.co/VlAAHHVzPm
#
# I'm at Corcoran's Grill &amp; Pub in Chicago, IL https://t.co/TleF34kgjH
#
#
# 95
# ['3', 'y', 'need_to', 'tho', 'rt', '??', '?!', 'hahaha', 'trash', '😳', 'talk_to', 'blood', 'unless', 'dumb', 'i', 'killed', 'trust', 'youre', 'last_year', 'vegas', 'sus', '@nickaxcx', 'a', 'mucho', 'wanna_drink', 'tavern', 'wed', 'someone_who', 'useless', 'grace']
# Next door to gios with guy drinking my bud nice n eating tacos
#
# @laz_city   it's that drunk Stu??
#
# drunk squinty eye out in full force @ Hopsmith Tavern https://t.co/decWTeRKND
#
# I wanna drink
#
# #watermelon #martini 🍸✌️ #perdition #NYC #cocktails #drinks #yummy @ Perdition NYC https://t.co/vDdcCEtNiK
#
# Ya la escucharon, no se enamoren, no es nada sencillo ver como se aleja tu mayor felicidad.
#
#
# 98
# ['...', 'alert_:', '#job_alert', '#sales', ',_tx', ':_retail', 'sales', ',', 'sales_-', 'houston', 'health_|', '|_#houston', 'retail_sales', '#retail', 'cosmetics_sales', '???', '-_beauty', '|_#newyork', 'more_than', 'the_beginning_of', ',_macy’s', 'vs', 'aerotek_|', 'commission_sales', ',..._-', '#veterans', ':..._-', '1st', '#healthcare_alert', '|_houston']
# Y is no one up to entertain me when I'm drinking at 11:30 on a Wednesday? ... Oh... They have normal jobs? ... That must suck #IPlayTrombone
#
# At work...
#
# Still disoriented &amp; drunk...
#
# From yesterday!
#
# FML
#
# Late night food...with some friends...after a night out drinking...good times, with awesome people! =) ♡♡ https://t.co/Wc9YGJ13Ur
#
# Have u guys ever tried chicken ginger rice porridge soup before?!
#
# #TweetMyJobs #Retail #Job alert: Part Time Sales | dressbarn | #Bronx, NY http://t.co/KcgN4zBB9p #Jobs #Hiring
#
# #Education #Job alert: Sign Language Interpreter Jobs in San Bernardino | Soliant Health | #SanBernandino, CA http://t.co/EdfhEaMLQp #Jobs
#
#
# 30
# [',', '.', 'a', 'mi', 'wrong', 'wtf', 'all_day', 'loving', 'un', '💀', 'wear', 'lead', 'usa', 'fucked_up', 'road', 'fresh', "when_you're", 'como', 'sexy', 'message', '@alejandrosanz', '.......', 'general', "can't_even", ':_p', 'died', 'scared', 'network', '5th', 'smokey']
# There's like 12 year olds drinking wtf we're becoming Germany
#
# Pineapple vodkas only. Gotta stay fresh.
#
# Katie's a funny drunk and Kylie pretty much turns into satan when intoxicated
#
# ITS SUMMER WHO CARES IF WERE FUCKED UP??? We ain't that drunk??
#
# 1996-Fue fácil instalarte en mi mente, pero te será difícil hacerlo en mi corazón.
#
# *REGALEMOS SILENCIO A LAS PALABRAS QUE NO FUERON DICHAS.
#
#
# 42
# ['#jobs_#hiring', '#glendale_,', 'in', '#nursing_#job', 'for_sale', "ain't", '.', 'az_)', 'wish', 'at', "i'll_be", 'haley', 'il_)', 'years', 'picture', ':_sr', 'mr', 'sales_lead', 'associate', 'month', 'medical_center', 'feel_like', 'imagine_if', 'dr', 'managing', '(#chicago_,', 'question', '#tempe_,', 'store_positions', '#veterans_#job']
# @DineshDSouza welcome home Dinesh!..God bless you!..go have a drink and a great steak!!..you earned it!!
#
# Kris Letang is getting married in a month and two days, somebody get me drunk 😭💔
#
# S/O 2 women who go down more than a submarine &amp; Roses r red, Pickles r green, we like your legs, Can we get in between?:@olivialeexxxx
#
# #fridaynight
# #nowork #goodtimes #knob #knobwhiskey #ice
# #brooklyn #nyc #cheers @ Diner https://t.co/d3JAebOCnT
#
# @eaterchicago Los Nopales Closes After 10 Years in Lincoln Square http://t.co/5HtDbMmWt8 http://t.co/9cDoy2EbSa
#
#
# 61
# ['smh', '#lovewins', '#ff', 'tx_)', 'taste', 'choice', 'your_life', 'pm', '😓', 'sister', 'your_own', '😍😍', 'nc_)', 'buying', 'brew', '😛', 'the_rest_of', '#art', 'accounting', 'dominican_republic', 'jr', 'as_long_as', 'taylor', 'corporate', '(#charlotte_,', 'rad', 'saludos', 'mother', 'on_top', 'ka']
# My parents are stingy w their beer smh
#
# When @agallagher106 almost gets in a fight with some drunk ass Gloucester trash #hardbody
#
# Rosemary's Greenpoint Tavern has stopped serving 32 oz styrofoam cups of beer. :'(
#
# Everytime I come to walgreens I'm either drunk buying beer or high as fuck buying a shit ton of cAndy
#
# uh oh mommas hashtaggin
#
#
# 59
# ['come', 'de', 'keep', 'ca_)', 'going', '😅', 'sad', 'follow_me', 'looks', 'somebody', 'dudes', 'turn', 'loves', 'the_first_time', '(#losangeles_,', 'sports', 'government', 'sleeping', '#nursing', '&gt;_&gt;_&gt;_&gt;', 'per', 'a', 'hoy', 'prefer', 'pro', '#facilitiesmgmt_#job', 'di', 'such_an', 'hc', '(#irvine_,']
# Unexpectedly failed that final 😅 lets drink lol
#
# Nothing like going to church hungover/still drunk 😅
#
# Sippen on some vodka straight out the bottle , nigga I be going hard like it's going full throttle.
#
# Drunk family members &gt;&gt;&gt;&gt; 😂
#
#
# 11
# ['-', '#sales_#job', 'bad', 'sales_representative', 'haha', 'feel', 'find', ':_senior', 'change', 'a_lot_of', ':_applications', 'might', 'oracle_:', ',_inc', 'cvs_health', 'registered_nurse', 'account_manager', 'entry_level', 'drivers', 'idea', 'drake', 'rn_/', 'my_best_friend', 'forget', 'tan', 'designer', 'my_head', 'at…', 'software_engineer', 'industry']
# Drunk xX Travis $cott / Young Thug 🔥
#
# Travis Scott and Young Thug - Drunk
#
# Hanging out at the bus stop… where is Katie Dawes??? - Drinking a Black &amp; Tan @ Cota Bus Stop - http://t.co/tsuIFHHddd
#
#
# 69
# ['because', 'again', 'babe', 'te', '.', 'lucky', '😴', 'response', 'however', 'trump', 'esta', 'looked', 'religion', 'hay', '#ontherocks', 'páginas_de', 'ever_been', 'steve', 'you_guys_are', 'lee', '😀', 'asshole', 'drunk_as_fuck', 'avi', 'vine', 'con_un', 'zero', 'members', 'on_fire', 'cuenta']
# Last nights beer of choice 👍🏻🍻 they've done it again!... (Cloudbusting) http://t.co/KkgWFjH7rj
#
# Gotta stop drinking or smoking because it's leaving me broke asf
#
# Getting drunk with @yupthatspayton because New Yorkers suck.
#
#
# 82
# ['this_#job', '#realestate', '#hiring', 'in', 'a', 'will_be', 'city', 'sales_consultant', '#sales_professional', 'sure', 'retail', '#irvine_,', 'goes', 'wanna', 'wale', 'public_relations', 'just_posted', 'booze', 'fight', 'photo_@', 'dream', '#marketing', 'spent', '☺️', 'app', 'out_here', 'a_video_tour', '#culvercity_,', '#engineering_professional', '#in']
# Play young and beautiful by lana del ray drunk your real feeling will come out!
#
# Still wanna drink heavily
#
# Just posted a photo @ Napa Valley Wine Country https://t.co/LTfJ5mq2xH
#
#
# -1
# ['shit', 'work', '…', 'la', 'big', '.', 'with', 'class', 'on', 'my', '7', 'fans', 'in', 'for', 'wines', 'youngin', 'the_worst', 'and', 'draft', 'the', 'somewhere', 'quick', 'last_week', 'til', 'yum', 'james', 'moved', "it_wasn't", 'pretty_much', 'freedom']
# Glamrockspliffbeerenotwerk

# %% [markdown]
# # Testing Pipeline

# %%
from sklearn.linear_model import LogisticRegression
from scipy.stats import uniform

from pipelines.alcohol import AlcoholPipeline
from data import iterate_heirarchy
from classification.compute import CustomGridSearch
from gridsearch import text_grid

# %%
param_grid = {
    'clf__C': uniform(0.01, 1000),
    'clf__class_weight': ["auto", None],
    'clf__penalty': ['l2', "l1"],
    'clf__tol': uniform(0.00001, 0.001),
    'clf__verbose': [0],
}

param_grid.update(text_grid)

cv_kwargs = dict(
    n_iter=200,
    scoring=None,
    fit_params=None,
    n_jobs=4,
    iid=True,
    refit=True,
    cv=None,
    verbose=3,
    pre_dispatch='2*n_jobs',
    error_score=0
)

# %%
from data.dao import DataAccess, LabelGetter

# %%
XX = DataAccess.get_as_dataframe()
LL = LabelGetter(XX)

# %%
X, y = LL.get_alcohol()

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# %%time
pipeline = AlcoholPipeline(global_features=["text"]).pipeline(LogisticRegression(C=30))
pipeline.fit(X_train, y_train)
# Out:
# CPU times: user 127 ms, sys: 2.37 ms, total: 129 ms
# Wall time: 128 ms

# %%
yy = pipeline.predict(X_test)

# %%
metrics.accuracy_score(yy, y_test)
# Out:
# 0.77572964669738864

# %%
metrics.f1_score(yy, y_test)
# Out:
# 0.80108991825613085
