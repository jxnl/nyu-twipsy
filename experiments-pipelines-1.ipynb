# %% [markdown]
# # Pipelines Exploration
#
# The purpose of a pipeline is to seamlessly fix various problems in the machine learning process
#
# * Data might not be in $R^d$
# * Features need to be engineered
# * Transformations need to be applied
# * Hyperparameters need to be tuned

# %%
from dao import DataAccess

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin

# %%
import numpy as np

# %% [markdown]
# First we easily instantiate a `DataAccess` and get the data in a DataFrame

# %%
X = DataAccess.as_dataframe()

# %%
X.head(2)
# Out:
#                                               created_at          labels  \
# _id
# 556e0ee3d6dfbb462880f0a5  Tue Jun 02 20:16:08 +0000 2015  {'alcohol': 0}
# 556e128ad6dfbb46288111e4  Tue Jun 02 20:31:44 +0000 2015  {'alcohol': 1}
#
#                            predict  \
# _id
# 556e0ee3d6dfbb462880f0a5  0.526050
# 556e128ad6dfbb46288111e4  0.516649
#
#                                                                        text  \
# _id
# 556e0ee3d6dfbb462880f0a5  Impatiently waiting to get our hands on the ne...
# 556e128ad6dfbb46288111e4  Beer fans need their @ColumbusBrewing Bodhi. I...
#
#                                                                        user
# _id
# 556e0ee3d6dfbb462880f0a5  {'verified': False, 'statuses_count': 823, 'fa...
# 556e128ad6dfbb46288111e4  {'verified': False, 'statuses_count': 10442, '...

# %%
class ExplodingRecordJoiner(BaseEstimator, TransformerMixin):
    def __init__(self, **kwargs):
        self.cols = kwargs
        
    def fit(self, X, y=None):
        pass
    
    def transform(self, X, y=None):
        # Extract column of dicts then apply from_records,
        # Match indicies then select the `subcols` we want,
        # Join with existing DataFrame.
        for col, subcol in self.cols.items():
            X = X.join(
                pd.DataFrame.from_records(X[col], index=X.index)[subcols]
            )
        return X
    
    def fit_transform(self, X, y=None):
        return self.transform(X)
    
    def __repr__(self):
        st = [k+"="+ str(v) for k,v in self.cols.items()]
        return "ExplodingRecordJoiner({})".format(", ".join(st))
    
    def get_params():
        return self.cols

# %%
ExplodingRecordJoiner(
    labels=["alcohol"],
    user=['created_at', 'favourites_count', 'followers_count', 
          'friends_count', 'statuses_count', 'verified']).get_params()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-b5b805cdbe34> in <module>()
#       2     labels=["alcohol"],
#       3     user=['created_at', 'favourites_count', 'followers_count',
# ----> 4           'friends_count', 'statuses_count', 'verified']).get_params()
#
# TypeError: get_params() takes 0 positional arguments but 1 was given

# %%
class ItemGetter(BaseEstimator, TransformerMixin):
    """
    This canonical ItemGetter is a Transformer for Pipeline objects.
    Initialize the ItemGetter with a `key` and its transform call will select a column out
    of the specified column.
    """
    
    def __init__(self, key):
        self.key = key
        
    def fit(self, X, y=None):
        pass
    
    def transform(self, X, y=None):
        return X[self.key]
    
    def fit_transform(self, X, y=None):
        return X[self.key]

# %% [markdown]
# ## Text Pipeline
#
# First on our list is a simple Text Pipeline that uses TfidfVectorizer and TruncatedSVD (LSI)
# Also use Twokenize from [brendano/tweetmotif](https://github.com/brendano/tweetmotif).
#
#     Brendan O'Connor, Michel Krieger, and David Ahn. TweetMotif: Exploratory Search and Topic Summarization for Twitter. ICWSM-2010.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

from twokenize import tokenize

text_pipe = []

text_pipe.append(
    ("text", 
     ItemGetter("text")
    )
)

text_pipe.append(
    ("tfidf", 
     TfidfVectorizer(
            analyzer="char",
            ngram_range=(2,5),
            min_df = 10,
            max_df = .98
        )
    )
)

text_pipe.append(
    ("lsi",
    TruncatedSVD(
            n_components=3000
        )
    )
)

# TruncatedSVD is annoying expensive...
text_pipeline = Pipeline(text_pipe[:2])

# %% [markdown]
# ### Future Work:
#
# Incorperate Gensim Phrases, and LDA as custom transformers with the ability to load them from files

# %% [markdown]
# # Time Pipeline
#
# ### Vectorizers
#
# I'll describe vectorization process a bit later as i've design it in a way so that it can be easily modified
# for future implementations.
#
# ### Transformers
#
# `DateTimeTransformer` takes the `created_at` selection and converts it into a `pandas.DatetimeIndex` which is amazingly powerful.
#
# Currently I am using the `dayofweek`, `hour`, and `hourofweek` features.

# %%
import pandas as pd

class Timestamp2DatetimeIndex(BaseEstimator, TransformerMixin):
    """
    This consumes a timestamp series and applies `pandas.DatetimeIndex`
    to return a DatetimeIndex object
    """
    def fit(self, X, y=None):
        pass
    
    def transform(self, X, y=None):
        return pd.DatetimeIndex(X)
    
    def fit_transform(self, X, y=None):
        return self.transform(X)

# %%
from scipy.sparse import csc_matrix

import pandas as pd

class DatetimeIndexAttr(BaseEstimator, TransformerMixin):
    """
    Accesses all of the available `pandas.DatetimeIndex` attributes when initialized.
    Also provides a new attribute called "hourofweek".
    """
    
    def __init__(self, kind):
        self.kind = kind
        
    def fit(self, X, y=None):
        pass
    
    def transform(self, X, y=None):
        n = len(X)
        if self.kind == "hourofweek":
            col = X.dayofweek * 24 + X.hour
        else:
            col = getattr(X, self.kind)
        return pd.DataFrame(col)
    
    def fit_transform(self, X, y=None):
        return self.transform(X)

# %% [markdown]
# Everything is one hot encoded, am I ashamed? A little...

# %%
from sklearn.preprocessing import OneHotEncoder

time_pipe = list()

time_pipe.append(
    ("get_created_at", 
     ItemGetter("created_at")
    )
)

time_pipe.append(
    ("to_datetimeindex",
    DateTimeTransformer()
    )
)

time_pipe.append(
    ("features",
    FeatureUnion([
        ("dayofweek", 
         Pipeline(
                    [("index", DatetimeIndex("dayofweek")),
                     ("onehot", OneHotEncoder())])),
        ("hour", 
         Pipeline(
                    [("index", DatetimeIndex("hour")),
                     ("onehot", OneHotEncoder())])),
        ("hourofweek", 
         Pipeline(
                    [("index", DatetimeIndex("hourofweek")),
                     ("onehot", OneHotEncoder())]))
        ])
    )
)

# %% [markdown]
# ### Future Work
#
# Notice that right now the things are all OneHotEncoded. This will change later. We see that a lot of this infromation is periodic so we can probably include features like the different between Phases rather than the time itself.
#
# This will probably function better than collapsing it into larger semantic intervals like `Afternoon` or `Sunday Afternoon`
#
# Moreover instead of using prior densities based on our other data, we could also have that a part of the fit process...

# %% [markdown]
# ## User Pipeline
#
# From prior exploration it seems that log scaling them helps a lot. Noreover, a feature called normality also helps greatly.

# %% [markdown]
# On read, There user column is a dict so we need a transformer to convert it.

# %%
class Dict2DF(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        pass
    
    def transform(self, X, y=None):
        return pd.DataFrame.from_records(X, index=X.index)
    
    def fit_transform(self, X, y=None):
        return self.transform(X)

# %%
u = Dict2DF().fit_transform(X.user).head()

# %%
u
# Out:
#                                               created_at  favourites_count  \
# _id
# 556e0ee3d6dfbb462880f0a5  Thu Jun 12 22:14:05 +0000 2014               394
# 556e128ad6dfbb46288111e4  Mon Oct 06 21:00:38 +0000 2008               806
# 556e1464d6dfbb4628812330  Sun Mar 11 08:22:56 +0000 2012               860
# 556e15f1d6dfbb4628813236  Thu Jan 14 03:03:33 +0000 2010              3473
# 556e1adcd6dfbb50e34a1ed6  Sun Oct 24 23:02:03 +0000 2010              3964
#
#                           followers_count  friends_count  statuses_count  \
# _id
# 556e0ee3d6dfbb462880f0a5              407           1997             823
# 556e128ad6dfbb46288111e4             1006            960           10442
# 556e1464d6dfbb4628812330              703            684           89573
# 556e15f1d6dfbb4628813236             9414           1486           16435
# 556e1adcd6dfbb50e34a1ed6              519            434           32154
#
#                          verified
# _id
# 556e0ee3d6dfbb462880f0a5    False
# 556e128ad6dfbb46288111e4    False
# 556e1464d6dfbb4628812330    False
# 556e15f1d6dfbb4628813236     True
# 556e1adcd6dfbb50e34a1ed6    False

# %%
class UserEgoVectorizer(BaseEstimator, TransformerMixin):
    
    def __init__(self, log=True, mean=True):
        self.log = log
        self.mean = mean
    
    def fit(self, X, y=None):
        
        u = X
        
        if self.log:
            favourites_count = np.log(u.favourites_count)
            followers_count = np.log(u.followers_count)
            statuses_count = np.log(u.statuses_count)
        
        if self.mean:
            self.mean_fav = np.mean(u.favourites_count)
            self.mean_fol = np.mean(u.followers_count)
            self.mean_fri = np.mean(u.friends_count)
        return 
    
    def transform(self, X, y=None):
        
        u = X
        
        u["normality"] = u.friends_count / (u.followers_count + u.friends_count + 1)
        
        if self.log:
            u["log_favourites_count"] = np.log(u.favourites_count)
            u["log_followers_count"] = np.log(u.followers_count)
            u["log_statuses_count"] = np.log(u.statuses_count)
            u["log_friends_count"] = np.log(u.friends_count)
        
        if self.mean:
            u["fav_kre"] = (u.favourites_count - self.mean_fav) 
            u["fol_kre"] = (u.followers_count - self.mean_fol)
            u["fri_kre"] = (u.friends_count - self.mean_fri)
        del u["created_at"]
        return u
    
    def fit_transform(self, X, y=None):
        self.fit(X)
        return self.transform(X)

# %%
class UserAgeMonths(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        pass
    
    def transform(self, X, y=None):
        from operator import itemgetter
        tweet_time = pd.to_datetime(X.created_at)
        user_time = pd.to_datetime(X.user.apply(itemgetter("created_at")))
        return (tweet_time - user_time).apply(int) // 2.62974e15
    
    def fit_transform(self, X, y=None):
        self.fit(X)
        return self.transform(X)

# %%
pd.DataFrame.from_records(X.user, index=X.index).columns
# Out:
# Index(['created_at', 'favourites_count', 'followers_count', 'friends_count',
#        'statuses_count', 'verified'],
#       dtype='object')

# %%
X.join(pd.DataFrame.from_records(X.user, index=X.index), rsuffix="_user")
# Out:
#                                               created_at          labels  \
# _id
# 556e0ee3d6dfbb462880f0a5  Tue Jun 02 20:16:08 +0000 2015  {'alcohol': 0}
# 556e128ad6dfbb46288111e4  Tue Jun 02 20:31:44 +0000 2015  {'alcohol': 1}
# 556e1464d6dfbb4628812330  Tue Jun 02 20:39:37 +0000 2015  {'alcohol': 1}
# 556e15f1d6dfbb4628813236  Tue Jun 02 20:46:14 +0000 2015  {'alcohol': 1}
# 55917457d6dfbb4e77e288c1  Because drinking at 11:30 in the morning is a ...
# 559176cad6dfbb4e77e290fc  Fuggin beaners got caught vaping in class thin...
# 55918fa3d6dfbb56098ac174             i can drink out of a straw yay yay yay
# 5591980cd6dfbb5a81838136  Tonight's the night for time traveling and dri...
# 55919949d6dfbb5a81838d6f  Someone took my phone and put their number in ...
# 55919c45d6dfbb5a8183a5e1  I have to have a drink b4 and after work maybe...
# 55919cead6dfbb5a8183acd9        drinking games with white people so fun 😂🙌🏾
# 55919d9fd6dfbb5a8183b396  So ... \n\nMy Mom Walked Home With Case Load F...
# 5591a2b8d6dfbb5a8183d4d9  If I could figure out a way of trading beer fo...
# 5591a5a6d6dfbb62c62a8dd9         my drinks spill on me, while I feel on you
# 5591a6e2d6dfbb62c62a9a65  Finally, 2nd male suspect was caught yesterday...
# 5591a73ad6dfbb62c62a9e08             Imagine Dragons in Jersey tonight .. 🎶
# 5591a974d6dfbb62c62aaf79  I like how much Brandon can drink 👍 pretty awe...
# 5591acb2d6dfbb62c62acfe8  Debating on drinking today because Ashley isn'...
# 5591b008d6dfbb62c62af173  when boul grabbed his drinks then start runnin...
# 5591b30dd6dfbb717339f39c             Call your friends let's get drunkkkkk.
# 5591b460d6dfbb71733a0074  Serving dinner at @TheMapleLeafPub \n\n6-9:30p...
# 5591b49ad6dfbb71733a02c7  Big root beer smell and taste -\nYou may forge...
# 5591b6f5d6dfbb71733a182a  ITS SUMMER WHO CARES IF WERE FUCKED UP??? We a...
# 557ca570d6dfbb7ac08b44f5  Beer stains and more beer on our merch table l...
# 55790537d6dfbb3f4bb7712f  There are beer choices for just about every ta...
#
#                                                                        user  \
# _id
# 556e0ee3d6dfbb462880f0a5  {'verified': False, 'statuses_count': 823, 'fa...
# 556e128ad6dfbb46288111e4  {'verified': False, 'statuses_count': 10442, '...
# 556e1464d6dfbb4628812330  {'verified': False, 'statuses_count': 89573, '...
# 556e15f1d6dfbb4628813236  {'verified': True, 'statuses_count': 16435, 'f...
# 556e1adcd6dfbb50e34a1ed6  {'verified': False, 'statuses_count': 32154, '...
# 556e1e58d6dfbb50e34a3eb7  {'verified': False, 'statuses_count': 12889, '...
# 556e2133d6dfbb50e34a59c8  {'verified': False, 'statuses_count': 778, 'fa...
# 556e2484d6dfbb50e34a7958  {'verified': False, 'statuses_count': 23532, '...
# 556e3d1ed6dfbb6d1e39fe92  {'verified': False, 'statuses_count': 11567, '...
# 556e3dfcd6dfbb6d1e3a075e  {'verified': False, 'statuses_count': 794, 'fa...
# 556e4274d6dfbb6d1e3a3504  {'verified': False, 'statuses_count': 7060, 'f...
# 556e4332d6dfbb6d1e3a3ca5  {'verified': False, 'statuses_count': 2673, 'f...
# 556e4560d6dfbb7a8de41bf7  {'verified': False, 'statuses_count': 7762, 'f...
# 556e456cd6dfbb7a8de41c6b  {'verified': False, 'statuses_count': 12067, '...
# 556e4632d6dfbb7a8de424ae  {'verified': False, 'statuses_count': 31666, '...
# 556e46dcd6dfbb7a8de42c34  {'verified': False, 'statuses_count': 21824, '...
# 556e46ead6dfbb7a8de42cd7  {'verified': False, 'statuses_count': 346, 'fa...
# 556e4aa7d6dfbb7a8de45705  {'verified': False, 'statuses_count': 2370, 'f...
# 556e4b48d6dfbb7a8de45dee  {'verified': False, 'statuses_count': 1849, 'f...
# 556e4c08d6dfbb7a8de4664a  {'verified': False, 'statuses_count': 3563, 'f...
# 556e4d00d6dfbb7a8de47165  {'verified': False, 'statuses_count': 1180, 'f...
# 556e4db1d6dfbb7a8de479b7  {'verified': False, 'statuses_count': 251, 'fa...
# 556e4ddcd6dfbb7a8de47b9c  {'verified': False, 'statuses_count': 14217, '...
# 556e4e1bd6dfbb7a8de47e81  {'verified': False, 'statuses_count': 1863, 'f...
# 556e4e47d6dfbb7a8de48083  {'verified': False, 'statuses_count': 5320, 'f...
# 556e4fbcd6dfbb7a8de49157  {'verified': False, 'statuses_count': 7291, 'f...
# 556e505bd6dfbb7a8de498ba  {'verified': False, 'statuses_count': 393, 'fa...
# 556e52fad6dfbb077d48274b  {'verified': False, 'statuses_count': 3869, 'f...
# 556e5510d6dfbb077d4841bf  {'verified': False, 'statuses_count': 8503, 'f...
# 556e556fd6dfbb077d48469d  {'verified': False, 'statuses_count': 3082, 'f...
# ...                                                                     ...
# 55914691d6dfbb3d910847c7  {'verified': False, 'statuses_count': 9733, 'f...
# 55914ac2d6dfbb3d91085bb3  {'verified': False, 'statuses_count': 490, 'fa...
# 55915050d6dfbb451b92c947  {'verified': False, 'statuses_count': 33164, '...
# 5591582bd6dfbb451b92f5e3  {'verified': False, 'statuses_count': 37113, '...
# 5591683ed6dfbb49d2d27098  {'verified': False, 'statuses_count': 350, 'fa...
# 559169f4d6dfbb49d2d27ea3  {'verified': False, 'statuses_count': 1319, 'f...
# 55916abfd6dfbb49d2d284c2  {'verified': False, 'statuses_count': 48005, '...
# 55916fb2d6dfbb4e77e26099  {'verified': False, 'statuses_count': 2061, 'f...
# 559173e0d6dfbb4e77e2857c  {'verified': False, 'statuses_count': 95893, '...
# 55917457d6dfbb4e77e288c1  {'verified': False, 'statuses_count': 2681, 'f...
# 559176cad6dfbb4e77e290fc  {'verified': False, 'statuses_count': 71, 'fav...
# 55918fa3d6dfbb56098ac174  {'verified': False, 'statuses_count': 4053, 'f...
# 5591980cd6dfbb5a81838136  {'verified': False, 'statuses_count': 138, 'fa...
# 55919949d6dfbb5a81838d6f  {'verified': False, 'statuses_count': 11808, '...
# 55919c45d6dfbb5a8183a5e1  {'verified': False, 'statuses_count': 4600, 'f...
# 55919cead6dfbb5a8183acd9  {'verified': False, 'statuses_count': 39723, '...
# 55919d9fd6dfbb5a8183b396  {'verified': False, 'statuses_count': 97636, '...
# 5591a2b8d6dfbb5a8183d4d9  {'verified': False, 'statuses_count': 2938, 'f...
# 5591a5a6d6dfbb62c62a8dd9  {'verified': False, 'statuses_count': 6264, 'f...
# 5591a6e2d6dfbb62c62a9a65  {'verified': False, 'statuses_count': 44829, '...
# 5591a73ad6dfbb62c62a9e08  {'verified': False, 'statuses_count': 15059, '...
# 5591a974d6dfbb62c62aaf79  {'verified': False, 'statuses_count': 25211, '...
# 5591acb2d6dfbb62c62acfe8  {'verified': False, 'statuses_count': 99315, '...
# 5591b008d6dfbb62c62af173  {'verified': False, 'statuses_count': 9013, 'f...
# 5591b30dd6dfbb717339f39c  {'verified': False, 'statuses_count': 12785, '...
# 5591b460d6dfbb71733a0074  {'verified': False, 'statuses_count': 1682, 'f...
# 5591b49ad6dfbb71733a02c7  {'verified': False, 'statuses_count': 9086, 'f...
# 5591b6f5d6dfbb71733a182a  {'verified': False, 'statuses_count': 16309, '...
# 557ca570d6dfbb7ac08b44f5  {'verified': False, 'statuses_count': 870, 'fa...
# 55790537d6dfbb3f4bb7712f  {'verified': False, 'statuses_count': 330, 'fa...
#
#                                          created_at_user  favourites_count  \
# _id
# 556e0ee3d6dfbb462880f0a5  Thu Jun 12 22:14:05 +0000 2014               394
# 556e128ad6dfbb46288111e4  Mon Oct 06 21:00:38 +0000 2008               806
# 556e1464d6dfbb4628812330  Sun Mar 11 08:22:56 +0000 2012               860
# 556e15f1d6dfbb4628813236  Thu Jan 14 03:03:33 +0000 2010              3473
# 556e1adcd6dfbb50e34a1ed6  Sun Oct 24 23:02:03 +0000 2010              3964
# 556e1e58d6dfbb50e34a3eb7  Tue Jul 29 13:51:57 +0000 2008              2489
# 556e2133d6dfbb50e34a59c8  Thu Mar 26 13:25:53 +0000 2015                 0
# 556e2484d6dfbb50e34a7958  Tue Jun 11 18:43:03 +0000 2013              1133
# 556e3d1ed6dfbb6d1e39fe92  Tue Nov 02 17:30:02 +0000 2010              3466
# 556e3dfcd6dfbb6d1e3a075e  Thu Sep 12 23:00:31 +0000 2013               608
# 556e4274d6dfbb6d1e3a3504  Sun Jan 23 02:07:59 +0000 2011               495
# 556e4332d6dfbb6d1e3a3ca5  Thu Nov 01 19:19:11 +0000 2012              3261
# 556e4560d6dfbb7a8de41bf7  Fri May 18 16:59:57 +0000 2012              4145
# 556e456cd6dfbb7a8de41c6b  Mon Apr 20 14:16:24 +0000 2009              4856
# 556e4632d6dfbb7a8de424ae  Sat Oct 03 23:15:08 +0000 2009               679
# 556e46dcd6dfbb7a8de42c34  Tue Apr 01 06:00:39 +0000 2008              5401
# 556e46ead6dfbb7a8de42cd7  Wed Apr 01 02:19:34 +0000 2009               165
# 556e4aa7d6dfbb7a8de45705  Tue Jul 21 05:44:49 +0000 2009               371
# 556e4b48d6dfbb7a8de45dee  Wed Jul 30 01:20:33 +0000 2014               544
# 556e4c08d6dfbb7a8de4664a  Tue Apr 08 17:08:40 +0000 2014              1344
# 556e4d00d6dfbb7a8de47165  Thu May 21 18:41:51 +0000 2015                 0
# 556e4db1d6dfbb7a8de479b7  Sat May 03 13:23:31 +0000 2014              1107
# 556e4ddcd6dfbb7a8de47b9c  Tue Dec 27 16:53:05 +0000 2011              5522
# 556e4e1bd6dfbb7a8de47e81  Sat Oct 26 15:12:10 +0000 2013              1428
# 556e4e47d6dfbb7a8de48083  Tue Apr 21 18:45:03 +0000 2009              2196
# 55790537d6dfbb3f4bb7712f  Sun Oct 07 22:22:07 +0000 2012                 1
#
#                           followers_count  friends_count  statuses_count  \
# _id
# 556e0ee3d6dfbb462880f0a5              407           1997             823
# 556e128ad6dfbb46288111e4             1006            960           10442
# 556e1464d6dfbb4628812330              703            684           89573
# 556e15f1d6dfbb4628813236             9414           1486           16435
# 556e1adcd6dfbb50e34a1ed6              519            434           32154
# 556e1e58d6dfbb50e34a3eb7              727            624           12889
# 556e2133d6dfbb50e34a59c8               13             42             778
# 556e2484d6dfbb50e34a7958             1912            699           23532
# 556e3d1ed6dfbb6d1e39fe92              309            173           11567
# 556e3dfcd6dfbb6d1e3a075e             1626            428             794
# 556e4274d6dfbb6d1e3a3504              143            178            7060
# 556e4332d6dfbb6d1e3a3ca5              282            488            2673
# 556e4560d6dfbb7a8de41bf7             2125           2330            7762
# 556e456cd6dfbb7a8de41c6b              274           1172           12067
# 556e4632d6dfbb7a8de424ae             1469           1127           31666
# 556e46dcd6dfbb7a8de42c34             1446           1499           21824
# 556e46ead6dfbb7a8de42cd7              193            528             346
# 556e4aa7d6dfbb7a8de45705               97            675            2370
# 556e4b48d6dfbb7a8de45dee              106            272            1849
# 556e4c08d6dfbb7a8de4664a              152            424            3563
# 556e4d00d6dfbb7a8de47165                1              0            1180
# 556e4db1d6dfbb7a8de479b7              522            883             251
# 556e4ddcd6dfbb7a8de47b9c              642           1779           14217
# 556e4e1bd6dfbb7a8de47e81              295            245            1863
# 556e4e47d6dfbb7a8de48083              134            122            5320
# 556e4fbcd6dfbb7a8de49157              250            327            7291
# 556e505bd6dfbb7a8de498ba              157            150             393
# 556e52fad6dfbb077d48274b               71             77            3869
# 556e5510d6dfbb077d4841bf              957            946            8503
# 556e556fd6dfbb077d48469d              139            233            3082
# ...                                   ...            ...             ...
# 55914691d6dfbb3d910847c7              592            334            9733
# 55914ac2d6dfbb3d91085bb3              212            435             490
# 55915050d6dfbb451b92c947              764            470           33164
# 5591582bd6dfbb451b92f5e3             1647           1084           37113
# 5591683ed6dfbb49d2d27098              348            331             350
# 559169f4d6dfbb49d2d27ea3               58             83            1319
# 55916abfd6dfbb49d2d284c2             2412           1875           48005
# 55916fb2d6dfbb4e77e26099             4559           4443            2061
# 559173e0d6dfbb4e77e2857c             2299           2034           95893
# 55917457d6dfbb4e77e288c1              131            120            2681
# 559176cad6dfbb4e77e290fc               39             59              71
# 55918fa3d6dfbb56098ac174              771            525            4053
# 5591980cd6dfbb5a81838136               65            258             138
# 55919949d6dfbb5a81838d6f              193             65           11808
# 55919c45d6dfbb5a8183a5e1              163            133            4600
# 55919cead6dfbb5a8183acd9             1695            889           39723
# 55919d9fd6dfbb5a8183b396             4926            455           97636
# 5591a2b8d6dfbb5a8183d4d9             4523           4887            2938
# 5591a5a6d6dfbb62c62a8dd9              334            233            6264
# 5591a6e2d6dfbb62c62a9a65              361            943           44829
# 5591a73ad6dfbb62c62a9e08              450            235           15059
# 5591a974d6dfbb62c62aaf79              215            181           25211
# 5591acb2d6dfbb62c62acfe8             1445            980           99315
# 5591b008d6dfbb62c62af173              337            359            9013
# 5591b30dd6dfbb717339f39c             2667           2519           12785
# 5591b460d6dfbb71733a0074             2556           1783            1682
# 5591b49ad6dfbb71733a02c7              315            261            9086
# 5591b6f5d6dfbb71733a182a              893            635           16309
# 557ca570d6dfbb7ac08b44f5              275            457             870
# 55790537d6dfbb3f4bb7712f               49            175             330
#
#                          verified
# _id
# 556e0ee3d6dfbb462880f0a5    False
# 556e128ad6dfbb46288111e4    False
# 556e1464d6dfbb4628812330    False
# 556e15f1d6dfbb4628813236     True
# 556e1adcd6dfbb50e34a1ed6    False
# 556e1e58d6dfbb50e34a3eb7    False
# 556e2133d6dfbb50e34a59c8    False
# 556e2484d6dfbb50e34a7958    False
# 556e3d1ed6dfbb6d1e39fe92    False
# 556e3dfcd6dfbb6d1e3a075e    False
# 556e4274d6dfbb6d1e3a3504    False
# 556e4332d6dfbb6d1e3a3ca5    False
# 556e4560d6dfbb7a8de41bf7    False
# 556e456cd6dfbb7a8de41c6b    False
# 556e4632d6dfbb7a8de424ae    False
# 556e46dcd6dfbb7a8de42c34    False
# 556e46ead6dfbb7a8de42cd7    False
# 556e4aa7d6dfbb7a8de45705    False
# 556e4b48d6dfbb7a8de45dee    False
# 556e4c08d6dfbb7a8de4664a    False
# 556e4d00d6dfbb7a8de47165    False
# 556e4db1d6dfbb7a8de479b7    False
# 556e4ddcd6dfbb7a8de47b9c    False
# 556e4e1bd6dfbb7a8de47e81    False
# 556e4e47d6dfbb7a8de48083    False
# 556e4fbcd6dfbb7a8de49157    False
# 556e505bd6dfbb7a8de498ba    False
# 556e52fad6dfbb077d48274b    False
# 556e5510d6dfbb077d4841bf    False
# 556e556fd6dfbb077d48469d    False
# ...                           ...
# 55914691d6dfbb3d910847c7    False
# 55914ac2d6dfbb3d91085bb3    False
# 55915050d6dfbb451b92c947    False
# 5591582bd6dfbb451b92f5e3    False
# 5591683ed6dfbb49d2d27098    False
# 559169f4d6dfbb49d2d27ea3    False
# 55916abfd6dfbb49d2d284c2    False
# 55916fb2d6dfbb4e77e26099    False
# 559173e0d6dfbb4e77e2857c    False
# 55917457d6dfbb4e77e288c1    False
# 559176cad6dfbb4e77e290fc    False
# 55918fa3d6dfbb56098ac174    False
# 5591980cd6dfbb5a81838136    False
# 55919949d6dfbb5a81838d6f    False
# 55919c45d6dfbb5a8183a5e1    False
# 55919cead6dfbb5a8183acd9    False
# 55919d9fd6dfbb5a8183b396    False
# 5591a2b8d6dfbb5a8183d4d9    False
# 5591a5a6d6dfbb62c62a8dd9    False
# 5591a6e2d6dfbb62c62a9a65    False
# 5591a73ad6dfbb62c62a9e08    False
# 5591a974d6dfbb62c62aaf79    False
# 5591acb2d6dfbb62c62acfe8    False
# 5591b008d6dfbb62c62af173    False
# 5591b30dd6dfbb717339f39c    False
# 5591b460d6dfbb71733a0074    False
# 5591b49ad6dfbb71733a02c7    False
# 5591b6f5d6dfbb71733a182a    False
# 557ca570d6dfbb7ac08b44f5    False
# 55790537d6dfbb3f4bb7712f    False
#
# [3165 rows x 11 columns]
